# %%
import mne
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from keras.models import Sequential
from keras.layers import LSTM, Dense,Dropout,TimeDistributed,GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from sklearn.model_selection import StratifiedShuffleSplit
from imblearn.over_sampling import SMOTE

# %%
# โหลดข้อมูล
df = pd.read_csv("C:\\Users\\ADMIN\Project\\.venv\\Sleep testFiltered_EEG_Data1.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24056\2419121426.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("C:\\Users\\ADMIN\Project\\.venv\\Sleep testFiltered_EEG_Data1.csv")

# %%
channel_map = {
    "1": "EEG F4-M1",
    "2": "EEG C4-M1",
    "3": "EEG O2-M1",
    "4": "EEG C3-M2",
    "5": "EMG chin",
    "6": "EOG E1-M2",
    "7": "EOG E2-M2",
    "8": "ECG"
}
# เปลี่ยนชื่อ column ใน DataFrame
df = df.rename(columns=channel_map)

# ตรวจสอบ
print(df.head())
# Out:
#        Time  EEG F4-M1  EEG C4-M1  EEG O2-M1  EEG C3-M2  EMG chin  EOG E1-M2  \
# 0  0.000000  -0.332139   1.460207  -0.082405   0.945965 -0.556532   8.282122
# 1  0.003906   0.455678  -0.506964  -8.182390   2.241613  3.137224  18.753385
# 2  0.007812  -0.995135  -3.805043 -15.517629   2.785924  5.121238  26.958536
# 3  0.011719  -5.017469  -7.255061 -18.758616   1.417463  5.081020  29.945681
# 4  0.015625 -10.258652  -9.017413 -16.288979  -2.295541  4.092776  27.027844
#
#    EOG E2-M2        ECG      Annotation
# 0  -6.846270 -36.322502   Sleep stage W
# 1  -6.397049 -36.334116   Sleep stage W
# 2  -7.204251 -37.603388   Sleep stage W
# 3  -9.951360 -42.065282   Sleep stage W
# 4 -13.573874 -50.681696   Sleep stage W

# %%
data = df.drop(['Annotation','Time'], axis=1)
labels = df['Annotation']

# %%
N2,W,R,N1,N3=labels.value_counts()
print(N2+W+R+N1+N3)
print(labels.value_counts())
# Out:
# 6558720
# Annotation
# Sleep stage N2    3302400
# Sleep stage W     1159680
# Sleep stage R     1082880
# Sleep stage N1     837120
# Sleep stage N3     176640
# Name: count, dtype: int64

# %% [markdown]
# ## Dugon arnon

# %%
def get_segments(labels):
    """Return list of (start_idx, end_idx, label) for continuous segments"""
    segments = []
    start = 0
    current_label = labels[0]

    for i in range(1, len(labels)):
        if labels[i] != current_label:
            segments.append((start, i, current_label))
            start = i
            current_label = labels[i]

    segments.append((start, len(labels), current_label))
    return segments
segments = get_segments(labels)

valid_segments = [seg for seg in segments if (seg[1] - seg[0]) >= 256]
seg_df = pd.DataFrame(valid_segments, columns=['start', 'end', 'Annotation'])
seg_df["length"] = seg_df["end"] - seg_df["start"]

# %%
seg_df
# Out:
#       start      end       Annotation  length
# 0         0    61440    Sleep stage W   61440
# 1     61440   122880   Sleep stage N1   61440
# 2    122880   130560   Sleep stage N2    7680
# 3    130560   138240   Sleep stage N1    7680
# 4    138240   184320   Sleep stage N2   46080
# ..      ...      ...              ...     ...
# 94  5967360  5982720   Sleep stage N1   15360
# 95  5982720  6120960    Sleep stage W  138240
# 96  6120960  6159360   Sleep stage N1   38400
# 97  6159360  6481920   Sleep stage N2  322560
# 98  6481920  6558720    Sleep stage W   76800
#
# [99 rows x 4 columns]

# %%
seg_df_n3 = seg_df[seg_df['Annotation'] == ' Sleep stage N3']
print(seg_df_n3)
# Out:
#       start      end       Annotation  length
# 15   806400   821760   Sleep stage N3   15360
# 17   829440   844800   Sleep stage N3   15360
# 19   852480   898560   Sleep stage N3   46080
# 21   906240   921600   Sleep stage N3   15360
# 23   929280   936960   Sleep stage N3    7680
# 64  3571200  3609600   Sleep stage N3   38400
# 76  4945920  4976640   Sleep stage N3   30720
# 78  4984320  4992000   Sleep stage N3    7680

# %%
seg_df_R = seg_df[seg_df['Annotation'] == ' Sleep stage R']
print(seg_df_R)
# Out:
#       start      end      Annotation  length
# 31  1190400  1328640   Sleep stage R  138240
# 33  1336320  1382400   Sleep stage R   46080
# 49  2403840  2411520   Sleep stage R    7680
# 51  2419200  2426880   Sleep stage R    7680
# 70  3978240  4193280   Sleep stage R  215040
# 72  4200960  4416000   Sleep stage R  215040
# 83  5299200  5306880   Sleep stage R    7680
# 85  5345280  5790720   Sleep stage R  445440

# %%
seg_df_W = seg_df[seg_df['Annotation'] == ' Sleep stage W']
print(seg_df_W)
# Out:
#       start      end      Annotation  length
# 0         0    61440   Sleep stage W   61440
# 6    199680   207360   Sleep stage W    7680
# 10   268800   299520   Sleep stage W   30720
# 34  1382400  1474560   Sleep stage W   92160
# 40  1896960  1904640   Sleep stage W    7680
# 53  2434560  3079680   Sleep stage W  645120
# 55  3087360  3095040   Sleep stage W    7680
# 57  3102720  3118080   Sleep stage W   15360
# 73  4416000  4454400   Sleep stage W   38400
# 80  5007360  5030400   Sleep stage W   23040
# 87  5798400  5806080   Sleep stage W    7680
# 93  5959680  5967360   Sleep stage W    7680
# 95  5982720  6120960   Sleep stage W  138240
# 98  6481920  6558720   Sleep stage W   76800

# %%
seg_df_W = seg_df[seg_df['Annotation'] == ' Sleep stage N1']
print(seg_df_W)
# Out:
#       start      end       Annotation  length
# 1     61440   122880   Sleep stage N1   61440
# 3    130560   138240   Sleep stage N1    7680
# 5    184320   199680   Sleep stage N1   15360
# 7    207360   253440   Sleep stage N1   46080
# 9    261120   268800   Sleep stage N1    7680
# 11   299520   391680   Sleep stage N1   92160
# 13   629760   637440   Sleep stage N1    7680
# 25  1075200  1082880   Sleep stage N1    7680
# 27  1136640  1144320   Sleep stage N1    7680
# 29  1175040  1182720   Sleep stage N1    7680
# 32  1328640  1336320   Sleep stage N1    7680
# 35  1474560  1520640   Sleep stage N1   46080
# 37  1551360  1566720   Sleep stage N1   15360
# 39  1843200  1896960   Sleep stage N1   53760
# 41  1904640  1943040   Sleep stage N1   38400
# 43  2127360  2135040   Sleep stage N1    7680
# 45  2211840  2219520   Sleep stage N1    7680
# 47  2304000  2311680   Sleep stage N1    7680
# 52  2426880  2434560   Sleep stage N1    7680
# 54  3079680  3087360   Sleep stage N1    7680
# 56  3095040  3102720   Sleep stage N1    7680
# 58  3118080  3179520   Sleep stage N1   61440
# 60  3287040  3294720   Sleep stage N1    7680
# 62  3386880  3394560   Sleep stage N1    7680
# 66  3663360  3671040   Sleep stage N1    7680
# 68  3878400  3886080   Sleep stage N1    7680
# 71  4193280  4200960   Sleep stage N1    7680
# 74  4454400  4546560   Sleep stage N1   92160
# 81  5030400  5038080   Sleep stage N1    7680
# 84  5306880  5345280   Sleep stage N1   38400
# 86  5790720  5798400   Sleep stage N1    7680
# 88  5806080  5859840   Sleep stage N1   53760
# 90  5928960  5936640   Sleep stage N1    7680
# 92  5952000  5959680   Sleep stage N1    7680
# 94  5967360  5982720   Sleep stage N1   15360
# 96  6120960  6159360   Sleep stage N1   38400

# %%
seg_df_N2 = seg_df[seg_df['Annotation'] == ' Sleep stage N2']
print(seg_df_N2)
# Out:
#       start      end       Annotation  length
# 2    122880   130560   Sleep stage N2    7680
# 4    138240   184320   Sleep stage N2   46080
# 8    253440   261120   Sleep stage N2    7680
# 12   391680   629760   Sleep stage N2  238080
# 14   637440   806400   Sleep stage N2  168960
# 16   821760   829440   Sleep stage N2    7680
# 18   844800   852480   Sleep stage N2    7680
# 20   898560   906240   Sleep stage N2    7680
# 22   921600   929280   Sleep stage N2    7680
# 24   936960  1075200   Sleep stage N2  138240
# 26  1082880  1136640   Sleep stage N2   53760
# 28  1144320  1175040   Sleep stage N2   30720
# 30  1182720  1190400   Sleep stage N2    7680
# 36  1520640  1551360   Sleep stage N2   30720
# 38  1566720  1843200   Sleep stage N2  276480
# 42  1943040  2127360   Sleep stage N2  184320
# 44  2135040  2211840   Sleep stage N2   76800
# 46  2219520  2304000   Sleep stage N2   84480
# 48  2311680  2403840   Sleep stage N2   92160
# 50  2411520  2419200   Sleep stage N2    7680
# 59  3179520  3287040   Sleep stage N2  107520
# 61  3294720  3386880   Sleep stage N2   92160
# 63  3394560  3571200   Sleep stage N2  176640
# 65  3609600  3663360   Sleep stage N2   53760
# 67  3671040  3878400   Sleep stage N2  207360
# 69  3886080  3978240   Sleep stage N2   92160
# 75  4546560  4945920   Sleep stage N2  399360
# 77  4976640  4984320   Sleep stage N2    7680
# 79  4992000  5007360   Sleep stage N2   15360
# 82  5038080  5299200   Sleep stage N2  261120
# 89  5859840  5928960   Sleep stage N2   69120
# 91  5936640  5952000   Sleep stage N2   15360
# 97  6159360  6481920   Sleep stage N2  322560

# %%
seg_counts = seg_df['Annotation'].value_counts()
print(seg_counts)
# Out:
# Annotation
# Sleep stage N1    36
# Sleep stage N2    33
# Sleep stage W     14
# Sleep stage N3     8
# Sleep stage R      8
# Name: count, dtype: int64

# %% [markdown]
# ## Select data

# %% [markdown]
# ### train set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_train = seg_df[
#     (
#         ((seg_df['start'] >= 806400) & (seg_df['end'] <= 821760)) |
#         ((seg_df['start'] >= 829440) & (seg_df['end'] <= 844800)) |
#         ((seg_df['start'] >= 852480) & (seg_df['end'] <= 898560)) |
#         ((seg_df['start'] >= 906240) & (seg_df['end'] <= 921600))
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_train = seg_df.loc[[15, 17, 19, 21]]

# %%
# selected_r_train = seg_df[
#     (
#         ((seg_df['start'] >= 3978240) & (seg_df['end'] <= 4070400)) #70
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
# ดึง row ที่ index = 31
r_seg = seg_df.loc[31]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_r_seg = pd.DataFrame([{
    'start': r_seg['start'],
    'end': r_seg['start'] + 92160,
    'Annotation': r_seg['Annotation'],
    'length': 92160
}])
selected_r_train = pd.concat([partial_r_seg], ignore_index=True)

# %%
selected_r_train
# Out:
#      start      end      Annotation  length
# 0  1190400  1282560   Sleep stage R   92160

# %%
# selected_w_train = seg_df[
#     (
#         ((seg_df['start'] >= 1382400) & (seg_df['end'] <= 1474560)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
selected_w_train = seg_df.loc[[34]]

# %%
# selected_n1_train = seg_df[
#     (
#         ((seg_df['start'] >= 299520) & (seg_df['end'] <= 391680)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N1')
# ]
selected_n1_train = seg_df.loc[[11]]

# %%
# selected_n2_train = seg_df[
#     (
#         ((seg_df['start'] >= 2311680) & (seg_df['end'] <= 2403840)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
selected_n2_train = seg_df.loc[[48]]

# %%
for name, df in {
    "N1": selected_n1_train,
    "N2": selected_n2_train,
    "N3": selected_n3_train,
    "R": selected_r_train,
    "W": selected_w_train
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 1 segments
# N2: 1 segments
# N3: 4 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Test set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_test = seg_df[
#     (
#         ((seg_df['start'] >= 929280) & (seg_df['end'] <= 936960)) |
#         ((seg_df['start'] >= 3571200) & (seg_df['end'] <= 3609600)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_test = seg_df.loc[[23,64]]

# %%
# selected_r_test = seg_df[
#     (
#         ((seg_df['start'] >= 1336320) & (seg_df['end'] <= 1382400)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
selected_r_test = seg_df.loc[[33]]

# %%
# selected_w_test = seg_df[
#     (
#         ((seg_df['start'] >= 0) & (seg_df['end'] <= 46080)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
w_seg_test = seg_df.loc[0]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_w_seg = pd.DataFrame([{
    'start': w_seg_test['start'],
    'end': w_seg_test['start'] + 46080,
    'Annotation': w_seg_test['Annotation'],
    'length': 92160
}])
selected_w_test = pd.concat([partial_w_seg], ignore_index=True)

# %%
# selected_n1_test = seg_df[
#     (
#         ((seg_df['start'] >= 1474560) & (seg_df['end'] <= 41520640)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N1')
# ]
selected_n1_test = seg_df.loc[[35]]

# %%
# selected_n2_test = seg_df[
#     (
#         ((seg_df['start'] >= 138240) & (seg_df['end'] <= 184320)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
selected_n2_test = seg_df.loc[[4]]

# %%
for name, df in {
    "N1": selected_n1_test,
    "N2": selected_n2_test,
    "N3": selected_n3_test,
    "R": selected_r_test,
    "W": selected_w_test
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 1 segments
# N2: 1 segments
# N3: 2 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Validate set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_val = seg_df[
#     (
#         ((seg_df['start'] >= 4945920) & (seg_df['end'] <= 4976640)) |
#         ((seg_df['start'] >= 4984320) & (seg_df['end'] <= 4992000)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_val = seg_df.loc[[76,78]]

# %%
# selected_r_val = seg_df[
#     (
#         ((seg_df['start'] >= 5345280) & (seg_df['end'] <= 5383680)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
r_seg_val = seg_df.loc[85]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_r_segval = pd.DataFrame([{
    'start': r_seg_val['start'],
    'end': r_seg_val['start'] + 38400,
    'Annotation': r_seg_val['Annotation'],
    'length': 92160
}])
selected_r_val = pd.concat([partial_r_segval], ignore_index=True)

# %%
# selected_w_val = seg_df[
#     (
#         ((seg_df['start'] >= 4416000) & (seg_df['end'] <= 4454400)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
selected_w_val = seg_df.loc[[73]]

# %%
# selected_n1_val = seg_df[
#     (
#         ((seg_df['start'] >= 1904640) & (seg_df['end'] <= 1943040)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N1')
# ]
selected_n1_val = seg_df.loc[[41]]

# %%
# selected_n2_val = seg_df[
#     (
#         ((seg_df['start'] >= 5859840) & (seg_df['end'] <= 5898240)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
n2_seg_val = seg_df.loc[89]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_n2_segval = pd.DataFrame([{
    'start': n2_seg_val['start'],
    'end': n2_seg_val['start'] + 38400,
    'Annotation': n2_seg_val['Annotation'],
    'length': 92160
}])
selected_n2_val = pd.concat([partial_n2_segval], ignore_index=True)

# %%
for name, df in {
    "N1": selected_n1_val,
    "N2": selected_n2_val,
    "N3": selected_n3_val,
    "R": selected_r_val,
    "W": selected_w_val
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 1 segments
# N2: 1 segments
# N3: 2 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Train/Test/Val Slit

# %%
# รวม segment ของ train/test/val แต่ละคลาส
train_segments = pd.concat([
    selected_n3_train,
    selected_r_train,
    selected_w_train,
    selected_n1_train,
    selected_n2_train
], ignore_index=True)

test_segments = pd.concat([
    selected_n3_test,
    selected_r_test,
    selected_w_test,
    selected_n1_test,
    selected_n2_test
], ignore_index=True)

val_segments = pd.concat([
    selected_n3_val,
    selected_r_val,
    selected_w_val,
    selected_n1_val,
    selected_n2_val
], ignore_index=True)

# %%
train_segments
# Out:
#      start      end       Annotation  length
# 0   806400   821760   Sleep stage N3   15360
# 1   829440   844800   Sleep stage N3   15360
# 2   852480   898560   Sleep stage N3   46080
# 3   906240   921600   Sleep stage N3   15360
# 4  1190400  1282560    Sleep stage R   92160
# 5  1382400  1474560    Sleep stage W   92160
# 6   299520   391680   Sleep stage N1   92160
# 7  2311680  2403840   Sleep stage N2   92160

# %%
test_segments
# Out:
#      start      end       Annotation  length
# 0   929280   936960   Sleep stage N3    7680
# 1  3571200  3609600   Sleep stage N3   38400
# 2  1336320  1382400    Sleep stage R   46080
# 3        0    46080    Sleep stage W   92160
# 4  1474560  1520640   Sleep stage N1   46080
# 5   138240   184320   Sleep stage N2   46080

# %%
val_segments
# Out:
#      start      end       Annotation  length
# 0  4945920  4976640   Sleep stage N3   30720
# 1  4984320  4992000   Sleep stage N3    7680
# 2  5345280  5383680    Sleep stage R   92160
# 3  4416000  4454400    Sleep stage W   38400
# 4  1904640  1943040   Sleep stage N1   38400
# 5  5859840  5898240   Sleep stage N2   92160

# %%
X_train_df = pd.concat([data.iloc[row.start:row.end] for _, row in train_segments.iterrows()]).reset_index(drop=True)
y_train_df = pd.concat([labels.iloc[row.start:row.end] for _, row in train_segments.iterrows()]).reset_index(drop=True)

X_test_df = pd.concat([data.iloc[row.start:row.end] for _, row in test_segments.iterrows()]).reset_index(drop=True)
y_test_df = pd.concat([labels.iloc[row.start:row.end] for _, row in test_segments.iterrows()]).reset_index(drop=True)

X_val_df = pd.concat([data.iloc[row.start:row.end] for _, row in val_segments.iterrows()]).reset_index(drop=True)
y_val_df = pd.concat([labels.iloc[row.start:row.end] for _, row in val_segments.iterrows()]).reset_index(drop=True)

# %%
X_train_df
# Out:
#         EEG F4-M1  EEG C4-M1  EEG O2-M1  EEG C3-M2  EMG chin  EOG E1-M2  \
# 0       11.988918  -9.800350   1.234130  -8.155535 -1.003727   0.444482
# 1       11.834525  -9.043753   3.469183  -6.757648 -1.875438   2.316137
# 2       10.006894 -11.314823   0.585498  -7.182482 -2.514637   2.795853
# 3        6.896737 -15.782217  -4.765642  -8.420605 -3.129654   3.601841
# 4        3.681137 -19.279838  -8.307767  -7.698028 -3.579161   5.977823
# ...           ...        ...        ...        ...       ...        ...
# 460795  -3.685817   3.478153   8.385379  -1.021841  3.023808 -12.887457
# 460796  -6.792157  -0.521728   2.413528  -3.069949  2.714382 -11.688400
# 460797  -8.702654  -1.252788   2.894249  -1.468036  2.174243  -7.976751
# 460798  -8.545341   2.253638   8.401847   3.189460  1.729178  -4.168177
# 460799  -8.086442   5.267957  11.459320   5.939815  1.141949  -2.707327
#
#         EOG E2-M2         ECG
# 0       -9.096484  126.184752
# 1       -7.901541  148.202564
# 2       -7.022960  178.106566
# 3       -5.600389  236.319262
# 4       -3.770041  328.201888
# ...           ...         ...
# 460795   2.401130   38.065769
# 460796   3.340073   36.101996
# 460797   5.085803   39.676452
# 460798   5.454691   48.016811
# 460799   3.850731   54.435447
#
# [460800 rows x 8 columns]

# %%
plt.figure(figsize=(13, 4))

# กำหนด offset สำหรับแต่ละชุด
offset_train = 0
offset_val = len(X_train_df)
offset_test = len(X_train_df) + len(X_val_df)

plt.plot(np.arange(offset_train, offset_train + len(X_train_df)),
         X_train_df['EEG F4-M1'], label='Training Set')

plt.plot(np.arange(offset_val, offset_val + len(X_val_df)),
         X_val_df['EEG F4-M1'], label='Validation Set')

plt.plot(np.arange(offset_test, offset_test + len(X_test_df)),
         X_test_df['EEG F4-M1'], label='Test Set')
plt.axvline(len(X_train_df), color='gray', linestyle='--')
plt.axvline(len(X_train_df) + len(X_val_df), color='gray', linestyle='--')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.title("EEG Signal (Channel F4-M1) split into Training, Validation, and Test Sets")
plt.xlabel("Time (samples)")
plt.ylabel("Amplitude")
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG F4-M1)
plt.plot(X_train_df.index, X_train_df['EEG F4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage W'],          # index ของ W
    X_train_df['EEG F4-M1'][y_train_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage N3'],          # index ของ W
    X_train_df['EEG F4-M1'][y_train_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage N1'],          # index ของ W
    X_train_df['EEG F4-M1'][y_train_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage R'],          # index ของ W
    X_train_df['EEG F4-M1'][y_train_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Training set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG F4-M1)
plt.plot(X_test_df.index, X_test_df['EEG F4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage W'],          # index ของ W
    X_test_df['EEG F4-M1'][y_test_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage N3'],          # index ของ W
    X_test_df['EEG F4-M1'][y_test_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage N1'],          # index ของ W
    X_test_df['EEG F4-M1'][y_test_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage R'],          # index ของ W
    X_test_df['EEG F4-M1'][y_test_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Test set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG F4-M1)
plt.plot(X_val_df.index, X_val_df['EEG F4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage W'],          # index ของ W
    X_val_df['EEG F4-M1'][y_val_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage N3'],          # index ของ W
    X_val_df['EEG F4-M1'][y_val_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage N1'],          # index ของ W
    X_val_df['EEG F4-M1'][y_val_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage R'],          # index ของ W
    X_val_df['EEG F4-M1'][y_val_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Validate set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
print("Train class distribution (%):")
print(y_train_df.value_counts(normalize=True) * 100)

print("\nTest class distribution (%):")
print(y_test_df.value_counts(normalize=True) * 100)

print("\nValidation class distribution (%):")
print(y_val_df.value_counts(normalize=True) * 100)
# Out:
# Train class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64
#
# Test class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64
#
# Validation class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64

# %%
y_train_df.value_counts(), y_val_df.value_counts(), y_test_df.value_counts()
# Out:
# (Annotation
#  Sleep stage N3    92160
#  Sleep stage R     92160
#  Sleep stage W     92160
#  Sleep stage N1    92160
#  Sleep stage N2    92160
#  Name: count, dtype: int64,
#  Annotation
#  Sleep stage N3    38400
#  Sleep stage R     38400
#  Sleep stage W     38400
#  Sleep stage N1    38400
#  Sleep stage N2    38400
#  Name: count, dtype: int64,
#  Annotation
#  Sleep stage N3    46080
#  Sleep stage R     46080
#  Sleep stage W     46080
#  Sleep stage N1    46080
#  Sleep stage N2    46080
#  Name: count, dtype: int64)

# %% [markdown]
# ### Select Channel

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460800 entries, 0 to 460799
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   EEG F4-M1  460800 non-null  float64
#  1   EEG C4-M1  460800 non-null  float64
#  2   EEG O2-M1  460800 non-null  float64
#  3   EEG C3-M2  460800 non-null  float64
#  4   EMG chin   460800 non-null  float64
#  5   EOG E1-M2  460800 non-null  float64
#  6   EOG E2-M2  460800 non-null  float64
#  7   ECG        460800 non-null  float64
# dtypes: float64(8)
# memory usage: 28.1 MB

# %%
selected_channels = ['EEG F4-M1', 'EEG C4-M1', 'EEG O2-M1','EEG C3-M2']

# Create the new DataFrame with only the selected channels
X_train_df_reduced = X_train_df[selected_channels]
X_val_df_reduced = X_val_df[selected_channels]
X_test_df_reduced = X_test_df[selected_channels]

X_train_df_reduced.shape, X_val_df_reduced.shape, X_test_df_reduced.shape
# Out:
# ((460800, 4), (192000, 4), (230400, 4))

# %% [markdown]
# ### Create Sliding Window

# %%
def apply_sliding_window(data, label, window_size, step_size):
    # Reset index เพื่อให้ iloc ทำงานได้แน่นอน
    data = data.reset_index(drop=True)
    label = label.reset_index(drop=True)

    window_data = []
    window_label = []

    for i in range(0, len(data) - window_size + 1, step_size):
        window = data.iloc[i:i + window_size]
        label_slice = label.iloc[i:i + window_size]

        # ตรวจว่าทั้ง window มี label เดียวกันไหม
        unique_labels = label_slice.unique()
        if len(unique_labels) == 1:  # ✅ มีคลาสเดียว
            window_data.append(window)
            window_label.append(unique_labels[0])
        else:
            continue  # 🚫 ถ้ามีมากกว่า 1 คลาส -> ข้ามเลย

    X = np.array(window_data)
    y = np.array(window_label)
    return X, y

# %%
# Define parameters
window_size = 256
step_size = 256

# Apply sliding window function to the train/test set
X_train, y_train =  apply_sliding_window(X_train_df, y_train_df, window_size, step_size)
X_val, y_val =  apply_sliding_window(X_val_df, y_val_df, window_size, step_size)
X_test, y_test = apply_sliding_window(X_test_df, y_test_df, window_size, step_size)

X_train_reduced, y_train_reduced =  apply_sliding_window(X_train_df_reduced, y_train_df, window_size, step_size)
X_val_reduced, y_val_reduced =  apply_sliding_window(X_val_df_reduced, y_val_df, window_size, step_size)
X_test_reduced, y_test_reduced = apply_sliding_window(X_test_df_reduced, y_test_df, window_size, step_size)

print("X_train:" ,X_train.shape, ", y_train:", y_train.shape)
print("X_val:" ,X_val.shape, ", y_val:", y_val.shape)
print("X_test:" ,X_test.shape, ", y_test:", y_test.shape)

print("X_train_reduced:" ,X_train_reduced.shape, ", y_train_reduced:", y_train_reduced.shape)
print("X_val_reduced:" ,X_val_reduced.shape, ", y_val_reduced:", y_val_reduced.shape)
print("X_test_reduced:" ,X_test_reduced.shape, ", y_test_reduced:", y_test_reduced.shape)
# Out:
# X_train: (1800, 256, 8) , y_train: (1800,)
# X_val: (750, 256, 8) , y_val: (750,)
# X_test: (900, 256, 8) , y_test: (900,)
# X_train_reduced: (1800, 256, 4) , y_train_reduced: (1800,)
# X_val_reduced: (750, 256, 4) , y_val_reduced: (750,)
# X_test_reduced: (900, 256, 4) , y_test_reduced: (900,)

# %%
print("Sample (original y_train_df):")
print(y_train_df.value_counts())
print("After Sliding Window (selected channels y_train_reduced):")
print(pd.Series(y_train_reduced).value_counts())
# รวมผลเป็น DataFrame เพื่อเทียบง่าย ๆ
annotation_check = pd.DataFrame({
    "N Sample": y_train_df.value_counts(),
}).fillna(0).astype(int)

print(annotation_check)
annotation_check.plot(kind="bar", figsize=(10, 5))
plt.title("N Sample Train set")
plt.ylabel("Count")
plt.xlabel("Sleep Stage")
plt.xticks(rotation=45)
plt.show()
print(y_train_df.value_counts(normalize=True) * 100)
# Out:
# Sample (original y_train_df):
# Annotation
# Sleep stage N3    92160
# Sleep stage R     92160
# Sleep stage W     92160
# Sleep stage N1    92160
# Sleep stage N2    92160
# Name: count, dtype: int64
# After Sliding Window (selected channels y_train_reduced):
# Sleep stage N3    360
# Sleep stage R     360
# Sleep stage W     360
# Sleep stage N1    360
# Sleep stage N2    360
# Name: count, dtype: int64
#                 N Sample
# Annotation
# Sleep stage N3     92160
# Sleep stage R      92160
# Sleep stage W      92160
# Sleep stage N1     92160
# Sleep stage N2     92160
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64

# %%
def clean_X_y(X, y):
    """Remove samples where y is NaN or 'nan' string"""
    # ตัดให้ X, y มีความยาวเท่ากันก่อน
    min_len = min(len(X), len(y))
    X = X[:min_len]
    y = y[:min_len]

    mask = ~(pd.isna(y) | (y == 'nan'))
    X_clean = X[mask]
    y_clean = y[mask]
    return X_clean, y_clean

# --- ลบ NaN และทำให้ขนาดตรงกัน ---
X_train, y_train = clean_X_y(X_train, y_train)
X_val, y_val     = clean_X_y(X_val, y_val)
X_test, y_test   = clean_X_y(X_test, y_test)

print("Shapes after cleaning NaN:")
print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:", X_val.shape, "y_val:", y_val.shape)
print("X_test:", X_test.shape, "y_test:", y_test.shape)
# Out:
# Shapes after cleaning NaN:
# X_train: (1800, 256, 8) y_train: (1800,)
# X_val: (750, 256, 8) y_val: (750,)
# X_test: (900, 256, 8) y_test: (900,)

# %% [markdown]
# ## Train

# %% [markdown]
# ### CNN(4CH)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.utils.class_weight import compute_class_weight

# %%
# -----------------------------
# 1. แปลง label เป็นตัวเลข + one-hot
# -----------------------------
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_val_enc   = encoder.transform(y_val)
y_test_enc  = encoder.transform(y_test)

num_classes = len(np.unique(y_train_enc))

y_train_cat = to_categorical(y_train_enc, num_classes=num_classes)
y_val_cat   = to_categorical(y_val_enc, num_classes=num_classes)
y_test_cat  = to_categorical(y_test_enc, num_classes=num_classes)

# -----------------------------
# 2. แปลง X ให้เป็น float32 และ shape = (samples, timesteps, features)
# -----------------------------
X_train = np.array(X_train_reduced, dtype=np.float32)
X_val   = np.array(X_val_reduced, dtype=np.float32)
X_test  = np.array(X_test_reduced, dtype=np.float32)

if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("X_train shape:", X_train.shape)  # (samples, timesteps, channels)
print("y_train shape:", y_train_cat.shape)

# -----------------------------
# 3. สร้าง CNN model
# -----------------------------
model_cnn = Sequential([
    Conv1D(filters=32, kernel_size=7, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=128, kernel_size=3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_cnn.summary()
# Out:
# X_train shape: (1800, 256, 4)
# y_train shape: (1800, 5)
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 250, 32)        │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 250, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 125, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 121, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 121, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 58, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 58, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 29, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 25, 64)         │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 25, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 177,189 (692.14 KB)
#  Trainable params: 176,613 (689.89 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
# --- Ensure all sets are same length ---
min_train_len = min(len(X_train), len(y_train_cat))
min_val_len   = min(len(X_val), len(y_val_cat))
min_test_len  = min(len(X_test), len(y_test_cat))

X_train = X_train[:min_train_len]
y_train_cat = y_train_cat[:min_train_len]

X_val = X_val[:min_val_len]
y_val_cat = y_val_cat[:min_val_len]

X_test = X_test[:min_test_len]
y_test_cat = y_test_cat[:min_test_len]

print("After sync:")
print("Train:", X_train.shape, y_train_cat.shape)
print("Val:  ", X_val.shape, y_val_cat.shape)
print("Test: ", X_test.shape, y_test_cat.shape)
# Out:
# After sync:
# Train: (1800, 256, 4) (1800, 5)
# Val:   (750, 256, 4) (750, 5)
# Test:  (900, 256, 4) (900, 5)

# %%
# -----------------------------
# 4. Train CNN model (no early stopping)
# -----------------------------
callbacks = [
    ModelCheckpoint('best_cnn_model.keras', monitor='val_loss', save_best_only=True)
]

history = model_cnn.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=100,
    batch_size=32,
    shuffle=True,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4933 - loss: 1.4515 - val_accuracy: 0.2547 - val_loss: 2.3558
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7072 - loss: 0.7440 - val_accuracy: 0.3213 - val_loss: 3.3256
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7867 - loss: 0.5434 - val_accuracy: 0.3573 - val_loss: 4.7379
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8372 - loss: 0.4152 - val_accuracy: 0.2813 - val_loss: 5.3842
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9006 - loss: 0.2777 - val_accuracy: 0.1693 - val_loss: 7.1181
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8967 - loss: 0.2743 - val_accuracy: 0.2293 - val_loss: 8.5900
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9172 - loss: 0.2190 - val_accuracy: 0.2200 - val_loss: 10.6884
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9044 - loss: 0.2617 - val_accuracy: 0.2173 - val_loss: 11.0472
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9283 - loss: 0.1962 - val_accuracy: 0.2040 - val_loss: 13.4742
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9283 - loss: 0.2127 - val_accuracy: 0.1533 - val_loss: 11.2829
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9450 - loss: 0.1543 - val_accuracy: 0.0587 - val_loss: 16.7378
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9578 - loss: 0.1118 - val_accuracy: 0.0760 - val_loss: 18.1574
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9517 - loss: 0.1515 - val_accuracy: 0.0947 - val_loss: 17.0394
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9944 - loss: 0.0183 - val_accuracy: 0.1933 - val_loss: 24.1427
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9972 - loss: 0.0071 - val_accuracy: 0.2000 - val_loss: 23.4567
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9967 - loss: 0.0121 - val_accuracy: 0.1760 - val_loss: 23.1643
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9967 - loss: 0.0125 - val_accuracy: 0.1973 - val_loss: 19.1868
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9939 - loss: 0.0237 - val_accuracy: 0.1573 - val_loss: 24.6908
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9944 - loss: 0.0192 - val_accuracy: 0.1893 - val_loss: 20.9594
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9972 - loss: 0.0085 - val_accuracy: 0.1880 - val_loss: 23.4583
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9839 - loss: 0.0598 - val_accuracy: 0.2040 - val_loss: 24.9236
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9739 - loss: 0.0915 - val_accuracy: 0.2320 - val_loss: 17.5009
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9906 - loss: 0.0404 - val_accuracy: 0.2027 - val_loss: 24.2484

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn.evaluate(X_test, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3600 - loss: 13.5051
# Test Loss: 13.5051, Test Accuracy: 36.00%

# %%
threshold = 0.5  # set the threshold value
y_pred_prob = model_cnn.predict(X_test)  # generate prediction probabilities
y_pred = (y_pred_prob > threshold).astype(int)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# --------------------------
# 1. Predict labels
# --------------------------
y_pred_probs = model_cnn.predict(X_test)   # ได้เป็น probability (softmax)
y_pred = np.argmax(y_pred_probs, axis=1)  # แปลงเป็น class index
y_true = np.argmax(y_test_cat, axis=1)    # แปลง one-hot y_test กลับเป็น index

# --------------------------
# 2. Confusion matrix
# --------------------------
cm = confusion_matrix(y_true, y_pred)

# --------------------------
# 3. Plot confusion matrix
# --------------------------
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# --------------------------
# 4. (optional) Classification report
# --------------------------
print(classification_report(y_true, y_pred, target_names=encoder.classes_))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00       180
#  Sleep stage N2       0.37      0.99      0.53       180
#  Sleep stage N3       0.35      0.20      0.26       180
#   Sleep stage R       0.97      0.61      0.75       180
#   Sleep stage W       0.00      0.00      0.00       180
#
#        accuracy                           0.36       900
#       macro avg       0.34      0.36      0.31       900
#    weighted avg       0.34      0.36      0.31       900

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
()
# Out:
# ()

# %%
print("Train class distribution:")
print(y_train_df.value_counts(normalize=True))

print("\nVal class distribution:")
print(y_val_df.value_counts(normalize=True))

print("\nTest class distribution:")
print(y_test_df.value_counts(normalize=True))
# Out:
# Train class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64
#
# Val class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64
#
# Test class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64

# %% [markdown]
# ## CNN(1CH)

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd

# ----------------------------------
# 🧹 1️⃣ ล้างช่องว่างซ้ายขวา + แปลงชื่อคลาสเป็นตัวเลข
# ----------------------------------
def clean_and_encode_labels(y):
    # แปลงเป็น string ทั้งหมดก่อน (เผื่อมีบางค่าเป็น int)
    y = pd.Series(y).astype(str).str.strip()
    
    label_map = {
        'Sleep stage N1': 0,
        'Sleep stage N2': 1,
        'Sleep stage N3': 2,
        'Sleep stage R': 3,
        'Sleep stage W': 4
    }
    
    # แปลงชื่อเป็นตัวเลข
    return y.replace(label_map).astype(int).values

# ใช้ฟังก์ชันกับทุกชุด
y_train_clean = clean_and_encode_labels(y_train)
y_val_clean   = clean_and_encode_labels(y_val)
y_test_clean  = clean_and_encode_labels(y_test)

print("✅ Unique y_train_clean:", np.unique(y_train_clean))
print("✅ Unique y_val_clean:", np.unique(y_val_clean))
print("✅ Unique y_test_clean:", np.unique(y_test_clean))

# ----------------------------------
# 2️⃣ แปลงเป็น one-hot
# ----------------------------------
num_classes = 5
y_train_cat = to_categorical(y_train_clean, num_classes)
y_val_cat   = to_categorical(y_val_clean, num_classes)
y_test_cat  = to_categorical(y_test_clean, num_classes)

# -----------------------------
# 🎯 เลือกเฉพาะ 1 channel ก่อนเข้า CNN
# -----------------------------
target_channel = "EEG F4-M1"

# กรณีข้อมูลหลัง sliding window เป็น numpy array
# เช่น X_train_reduced.shape = (samples, 256, 4)
channel_names = ['EEG F4-M1', 'EEG C4-M1', 'EEG O2-M1', 'EEG C3-M2']

# หา index ของ channel เป้าหมาย
ch_idx = channel_names.index(target_channel)

# ตัดเฉพาะช่องที่ต้องการ (เหลือเพียง 1 channel)
X_train = X_train_reduced[:, :, ch_idx:ch_idx+1]
X_val   = X_val_reduced[:, :, ch_idx:ch_idx+1]
X_test  = X_test_reduced[:, :, ch_idx:ch_idx+1]

print("✅ ใช้เฉพาะ channel:", target_channel)
print("X_train shape:", X_train.shape)

# -----------------------------
# 2. แปลง X ให้เป็น float32 และ shape = (samples, timesteps, features)
# -----------------------------
X_train = np.array(X_train, dtype=np.float32)
X_val   = np.array(X_val, dtype=np.float32)
X_test  = np.array(X_test, dtype=np.float32)

if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("X_train shape:", X_train.shape)  # (samples, timesteps, channels)
print("y_train shape:", y_train_cat.shape)

# -----------------------------
# 3. สร้าง CNN model
# -----------------------------
model_cnn = Sequential([
    Conv1D(filters=32, kernel_size=7, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=128, kernel_size=3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_cnn.summary()
# Out:
# ✅ Unique y_train_clean: [0 1 2 3 4]
# ✅ Unique y_val_clean: [0 1 2 3 4]
# ✅ Unique y_test_clean: [0 1 2 3 4]
# ✅ ใช้เฉพาะ channel: EEG F4-M1
# X_train shape: (1800, 256, 1)
# X_train shape: (1800, 256, 1)
# y_train shape: (1800, 5)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24056\14186043.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24056\14186043.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24056\14186043.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 250, 32)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 250, 32)        │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 125, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 121, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 121, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 58, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 58, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 29, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 25, 64)         │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 25, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        98,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 176,517 (689.52 KB)
#  Trainable params: 175,941 (687.27 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
print("✅ Unique y_train_clean:", np.unique(y_train_clean))
print("✅ Unique y_val_clean:", np.unique(y_val_clean))
print("✅ Unique y_test_clean:", np.unique(y_test_clean))
print("✅ num_classes:", num_classes)
print(type(y_train_clean[0]), type(y_val_clean[0]), type(y_test_clean[0]))
# Out:
# ✅ Unique y_train_clean: [0 1 2 3 4]
# ✅ Unique y_val_clean: [0 1 2 3 4]
# ✅ Unique y_test_clean: [0 1 2 3 4]
# ✅ num_classes: 5
# <class 'numpy.int64'> <class 'numpy.int64'> <class 'numpy.int64'>

# %%
# -----------------------------
# 4. Train CNN model
# -----------------------------
history = model_cnn.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=80,
    batch_size=32,
    shuffle=True,
)
# Out:
# Epoch 1/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.3539 - loss: 1.8343 - val_accuracy: 0.2320 - val_loss: 2.0004
# Epoch 2/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4694 - loss: 1.2695 - val_accuracy: 0.1973 - val_loss: 2.8434
# Epoch 3/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5417 - loss: 1.1160 - val_accuracy: 0.2160 - val_loss: 5.1887
# Epoch 4/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6256 - loss: 0.9517 - val_accuracy: 0.2027 - val_loss: 7.9757
# Epoch 5/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6500 - loss: 0.8750 - val_accuracy: 0.1947 - val_loss: 10.0163
# Epoch 6/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6756 - loss: 0.7983 - val_accuracy: 0.1960 - val_loss: 11.9613
# Epoch 7/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7061 - loss: 0.7357 - val_accuracy: 0.1973 - val_loss: 12.0576
# Epoch 8/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7433 - loss: 0.6483 - val_accuracy: 0.1987 - val_loss: 11.8772
# Epoch 9/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7772 - loss: 0.5697 - val_accuracy: 0.2080 - val_loss: 11.1550
# Epoch 10/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8178 - loss: 0.4905 - val_accuracy: 0.2040 - val_loss: 13.5260
# Epoch 11/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8117 - loss: 0.4899 - val_accuracy: 0.2093 - val_loss: 12.7572
# Epoch 12/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8394 - loss: 0.4349 - val_accuracy: 0.2040 - val_loss: 13.7979
# Epoch 13/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8467 - loss: 0.3886 - val_accuracy: 0.2040 - val_loss: 13.9390
# Epoch 14/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8822 - loss: 0.3366 - val_accuracy: 0.2120 - val_loss: 15.2402
# Epoch 15/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8861 - loss: 0.3326 - val_accuracy: 0.2053 - val_loss: 15.0589
# Epoch 16/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8644 - loss: 0.3839 - val_accuracy: 0.2000 - val_loss: 18.0839
# Epoch 17/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9033 - loss: 0.2706 - val_accuracy: 0.1987 - val_loss: 19.3059
# Epoch 18/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9250 - loss: 0.2083 - val_accuracy: 0.2013 - val_loss: 17.3134
# Epoch 19/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9272 - loss: 0.2150 - val_accuracy: 0.1987 - val_loss: 20.6789
# Epoch 20/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9411 - loss: 0.1639 - val_accuracy: 0.1987 - val_loss: 18.8119
# Epoch 21/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9361 - loss: 0.1812 - val_accuracy: 0.1960 - val_loss: 20.5857
# Epoch 22/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9489 - loss: 0.1467 - val_accuracy: 0.1987 - val_loss: 19.4945
# Epoch 23/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9467 - loss: 0.1529 - val_accuracy: 0.2000 - val_loss: 22.4263
# Epoch 24/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9400 - loss: 0.1641 - val_accuracy: 0.2027 - val_loss: 17.3612
# Epoch 25/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9467 - loss: 0.1427 - val_accuracy: 0.2027 - val_loss: 24.6744
# Epoch 26/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9539 - loss: 0.1250 - val_accuracy: 0.2013 - val_loss: 21.5144
# Epoch 27/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9478 - loss: 0.1376 - val_accuracy: 0.2053 - val_loss: 16.7313
# Epoch 28/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.
80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9833 - loss: 0.0480 - val_accuracy: 0.2013 - val_loss: 30.2764
# Epoch 60/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9861 - loss: 0.0498 - val_accuracy: 0.2000 - val_loss: 28.8430
# Epoch 61/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9822 - loss: 0.0510 - val_accuracy: 0.2000 - val_loss: 36.9516
# Epoch 62/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9783 - loss: 0.0517 - val_accuracy: 0.1933 - val_loss: 31.0815
# Epoch 63/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9822 - loss: 0.0518 - val_accuracy: 0.2013 - val_loss: 33.6017
# Epoch 64/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9833 - loss: 0.0528 - val_accuracy: 0.1987 - val_loss: 30.5824
# Epoch 65/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9861 - loss: 0.0478 - val_accuracy: 0.2053 - val_loss: 28.8708
# Epoch 66/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9828 - loss: 0.0479 - val_accuracy: 0.2053 - val_loss: 29.8713
# Epoch 67/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9889 - loss: 0.0362 - val_accuracy: 0.2053 - val_loss: 28.3336
# Epoch 68/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9906 - loss: 0.0239 - val_accuracy: 0.2013 - val_loss: 30.9871
# Epoch 69/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9878 - loss: 0.0340 - val_accuracy: 0.2040 - val_loss: 27.7407
# Epoch 70/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9889 - loss: 0.0293 - val_accuracy: 0.2027 - val_loss: 25.8126
# Epoch 71/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9733 - loss: 0.0792 - val_accuracy: 0.2040 - val_loss: 28.1969
# Epoch 72/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9689 - loss: 0.1031 - val_accuracy: 0.1987 - val_loss: 33.7840
# Epoch 73/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9633 - loss: 0.1120 - val_accuracy: 0.2040 - val_loss: 25.5555
# Epoch 74/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9783 - loss: 0.0661 - val_accuracy: 0.2027 - val_loss: 26.9709
# Epoch 75/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9644 - loss: 0.1006 - val_accuracy: 0.2040 - val_loss: 27.2494
# Epoch 76/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9739 - loss: 0.0647 - val_accuracy: 0.2013 - val_loss: 28.1878
# Epoch 77/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9711 - loss: 0.0752 - val_accuracy: 0.2000 - val_loss: 31.2620
# Epoch 78/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9867 - loss: 0.0454 - val_accuracy: 0.2040 - val_loss: 29.3521
# Epoch 79/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9872 - loss: 0.0420 - val_accuracy: 0.2013 - val_loss: 30.0959
# Epoch 80/80
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9911 - loss: 0.0288 - val_accuracy: 0.2013 - val_loss: 28.7481

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn.evaluate(X_test, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3011 - loss: 9.7317
# Test Loss: 9.7317, Test Accuracy: 30.11%

# %%
threshold = 0.5  # set the threshold value
y_pred_prob = model_cnn.predict(X_test)  # generate prediction probabilities
y_pred = (y_pred_prob > threshold).astype(int)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
()
# Out:
# ()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np

y_pred = model_cnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['N1','N2','N3','R','W'],
            yticklabels=['N1','N2','N3','R','W'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(y_true, y_pred_classes, target_names=['N1','N2','N3','R','W']))
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#           N1       0.19      0.17      0.18       180
#           N2       0.34      0.80      0.48       180
#           N3       0.12      0.10      0.11       180
#            R       0.50      0.31      0.38       180
#            W       0.35      0.13      0.19       180
#
#     accuracy                           0.30       900
#    macro avg       0.30      0.30      0.27       900
# weighted avg       0.30      0.30      0.27       900

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# ---- พยากรณ์บน validation set ----
y_val_pred_prob = model_cnn.predict(X_val)
y_val_pred = np.argmax(y_val_pred_prob, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

# ---- คำนวณ confusion matrix ----
cm_val = confusion_matrix(y_val_true, y_val_pred)
labels = encoder.classes_

# ---- แสดง confusion matrix ----
plt.figure(figsize=(7,6))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')
plt.show()

# ---- แสดง accuracy เพิ่มเติม ----
val_acc = np.mean(y_val_pred == y_val_true)
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Validation Accuracy: 0.2013

# %% [markdown]
# ## LSTM

# %%
# ----------------------------------
# 1️⃣ ฟังก์ชันแปลง label เป็นตัวเลข
# ----------------------------------
def clean_and_encode_labels(y):
    y = pd.Series(y).astype(str).str.strip()
    label_map = {
        'Sleep stage N1': 0,
        'Sleep stage N2': 1,
        'Sleep stage N3': 2,
        'Sleep stage R': 3,
        'Sleep stage W': 4
    }
    return y.replace(label_map).astype(int).values

# ----------------------------------
# 2️⃣ เตรียมข้อมูล (สมมติว่าคุณมี X_train, X_val, X_test, y_train, y_val, y_test)
# ----------------------------------
# ตัวอย่างโครงสร้าง (กรณีคุณโหลดข้อมูล EEG มาแล้ว)
# X_train.shape = (samples, timesteps, channels)
# เช่น X_train_reduced จากขั้นตอน sliding window
# หากเป็น array 2D จะเพิ่ม dimension ให้เอง

# 🔹 ใส่ข้อมูลของคุณตรงนี้ 🔹
# X_train, X_val, X_test, y_train, y_val, y_test = ...

# ----------------------------------
# 3️⃣ ทำความสะอาดและ encode label
# ----------------------------------
y_train_clean = clean_and_encode_labels(y_train)
y_val_clean   = clean_and_encode_labels(y_val)
y_test_clean  = clean_and_encode_labels(y_test)

num_classes = 5  # จำนวนคลาส N1, N2, N3, R, W

# แปลงเป็น one-hot
y_train_cat = to_categorical(y_train_clean, num_classes)
y_val_cat   = to_categorical(y_val_clean, num_classes)
y_test_cat  = to_categorical(y_test_clean, num_classes)

# ----------------------------------
# 4️⃣ ตรวจสอบ shape ของ X และแปลงเป็น float32
# ----------------------------------
X_train = np.array(X_train, dtype=np.float32)
X_val   = np.array(X_val, dtype=np.float32)
X_test  = np.array(X_test, dtype=np.float32)

# ถ้าเป็น 2D → เพิ่ม dimension (feature)
if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("✅ X_train shape:", X_train.shape)
print("✅ y_train shape:", y_train_cat.shape)

# ----------------------------------
# 5️⃣ สร้าง LSTM Model
# ----------------------------------
model_lstm = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model_lstm.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

model_lstm.summary()

# ----------------------------------
# 6️⃣ Train Model
# ----------------------------------
history = model_lstm.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=60,
    batch_size=32,
    shuffle=False,
    verbose=1
)

# ----------------------------------
# 7️⃣ Evaluate Model
# ----------------------------------
loss, acc = model_lstm.evaluate(X_test, y_test_cat)
print(f"✅ Test Loss: {loss:.4f}")
print(f"✅ Test Accuracy: {acc*100:.2f}%")

# ----------------------------------
# 8️⃣ Plot Learning Curves
# ----------------------------------
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------
# 9️⃣ Predict + Confusion Matrix (optional)
# ----------------------------------
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = model_lstm.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['N1','N2','N3','R','W'],
            yticklabels=['N1','N2','N3','R','W'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - LSTM')
plt.show()

print(classification_report(y_true, y_pred_classes, target_names=['N1','N2','N3','R','W']))
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_24056\171322584.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step
#               precision    recall  f1-score   support
#
#           N1       0.00      0.00      0.00       359
#           N2       0.29      0.41      0.34       359
#           N3       0.46      0.19      0.27       359
#            R       0.42      0.36      0.39       359
#            W       0.12      0.14      0.13       359
#
#     accuracy                           0.22      1795
#    macro avg       0.26      0.22      0.23      1795
# weighted avg       0.26      0.22      0.23      1795

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# ---- พยากรณ์บน validation set ----
y_val_pred_prob = model_lstm.predict(X_val)
y_val_pred = np.argmax(y_val_pred_prob, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

# ---- คำนวณ confusion matrix ----
cm_val = confusion_matrix(y_val_true, y_val_pred)

# ✅ ใช้ label ตามลำดับที่เรากำหนดไว้ใน clean_and_encode_labels()
labels = ['N1', 'N2', 'N3', 'R', 'W']

# ---- แสดง confusion matrix ----
plt.figure(figsize=(7,6))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')
plt.show()

# ---- แสดง accuracy เพิ่มเติม ----
val_acc = np.mean(y_val_pred == y_val_true)
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# Validation Accuracy: 0.1953

# %% [markdown]
# ## Spectrogram CNN

# %%
from scipy.signal import spectrogram
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# -----------------------------
# 1. Compute spectrogram function
# -----------------------------
def compute_spectrogram(signal, fs=100, nperseg=128, noverlap=64):
    f, t, Sxx = spectrogram(signal, fs=fs, nperseg=min(nperseg, len(signal)), 
                            noverlap=min(noverlap, len(signal)//2))
    return np.log1p(Sxx)

# -----------------------------
# 2. Transform X_train, X_val, X_test → Spectrogram
# -----------------------------
def dataset_to_spectrogram(X, fs=100, nperseg=128, noverlap=64):
    specs = []
    for x in X:  # x.shape = (timesteps, channels)
        ch_specs = [compute_spectrogram(x[:, ch], fs, nperseg, noverlap) 
                    for ch in range(x.shape[1])]
        specs.append(np.stack(ch_specs, axis=-1))  # (freq_bins, time_bins, channels)
    return np.array(specs)

# เพิ่ม channel dimension (เหมือนภาพขาวดำ)
# แปลง dataset ทั้งหมด
X_train_spec = dataset_to_spectrogram(X_train)
X_val_spec   = dataset_to_spectrogram(X_val)
X_test_spec  = dataset_to_spectrogram(X_test)

print("X_train_spec:", X_train_spec.shape)
print("X_val_spec:", X_val_spec.shape)
print("X_test_spec:", X_test_spec.shape)
# -----------------------------
# 3. Encode labels
# -----------------------------
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_val_enc   = encoder.transform(y_val)
y_test_enc  = encoder.transform(y_test)

num_classes = len(np.unique(y_train_enc))
y_train_cat = to_categorical(y_train_enc, num_classes=num_classes)
y_val_cat   = to_categorical(y_val_enc, num_classes=num_classes)
y_test_cat  = to_categorical(y_test_enc, num_classes=num_classes)

# -----------------------------
# 4. CNN Model (simple)
# -----------------------------
model_cnn_spec = Sequential([
    Conv2D(32, (3,3), activation='relu',padding='same', input_shape=X_train_spec.shape[1:]),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same',),

    Conv2D(64, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Conv2D(128, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Conv2D(64, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax',)
])

model_cnn_spec.compile(optimizer='adam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

model_cnn_spec.summary()
# Out:
# X_train_spec: (3595, 65, 3, 8)
# X_val_spec: (1495, 65, 3, 8)
# X_test_spec: (1795, 65, 3, 8)
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 65, 3, 32)      │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 65, 3, 32)      │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 33, 2, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 33, 2, 64)      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 33, 2, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 17, 1, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 17, 1, 128)     │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 17, 1, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 9, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 9, 1, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 9, 1, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 320)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        41,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 211,365 (825.64 KB)
#  Trainable params: 210,789 (823.39 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
# -----------------------------
# 5. Train model (no class weight)
# -----------------------------
history = model_cnn_spec.fit(
    X_train_spec, y_train_cat,
    validation_data=(X_val_spec, y_val_cat),
    epochs=200,
    batch_size=32,
    shuffle=True
)
# Out:
# Epoch 1/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9933 - loss: 0.0221 - val_accuracy: 0.2809 - val_loss: 18.8240
# Epoch 2/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9981 - loss: 0.0059 - val_accuracy: 0.2201 - val_loss: 24.2142
# Epoch 3/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.2047 - val_loss: 33.7551
# Epoch 4/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.2294 - val_loss: 35.4493
# Epoch 5/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9975 - loss: 0.0064 - val_accuracy: 0.2047 - val_loss: 28.3009
# Epoch 6/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9972 - loss: 0.0052 - val_accuracy: 0.2769 - val_loss: 27.5720
# Epoch 7/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9969 - loss: 0.0208 - val_accuracy: 0.2013 - val_loss: 32.1755
# Epoch 8/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9930 - loss: 0.0223 - val_accuracy: 0.2308 - val_loss: 25.7789
# Epoch 9/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9986 - loss: 0.0057 - val_accuracy: 0.2702 - val_loss: 24.5896
# Epoch 10/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9930 - loss: 0.0228 - val_accuracy: 0.1431 - val_loss: 38.4159
# Epoch 11/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9953 - loss: 0.0119 - val_accuracy: 0.2488 - val_loss: 34.6947
# Epoch 12/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9953 - loss: 0.0117 - val_accuracy: 0.2247 - val_loss: 31.9719
# Epoch 13/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.3064 - val_loss: 31.2898
# Epoch 14/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9975 - loss: 0.0104 - val_accuracy: 0.2047 - val_loss: 38.5333
# Epoch 15/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9969 - loss: 0.0083 - val_accuracy: 0.3130 - val_loss: 33.2509
# Epoch 16/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 3.8410e-04 - val_accuracy: 0.3090 - val_loss: 33.5248
# Epoch 17/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9997 - loss: 5.4341e-04 - val_accuracy: 0.2957 - val_loss: 34.3447
# Epoch 18/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 5.3297e-04 - val_accuracy: 0.3184 - val_loss: 34.4329
# Epoch 19/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.5308e-04 - val_accuracy: 0.3197 - val_loss: 34.6802
# Epoch 20/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 2.1257e-04 - val_accuracy: 0.3010 - val_loss: 34.7334
# Epoch 21/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 8.6503e-05 - val_accuracy: 0.3064 - val_loss: 34.6416
# Epoch 22/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.7377e-04 - val_accuracy: 0.2615 - val_loss: 35.9655
# Epoch 23/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 7.1600e-05 - val_accuracy: 0.2843 - val_loss: 35.6909
# Epoch 24/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 2.2314e-04 - val_accuracy: 0.2368 - val_loss: 35.9126
# Epoch 25/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9911 - loss: 0.0276 - val_accuracy: 0.2254 - val_loss: 34.4742
# Epoch 26/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9900 - loss: 0.0357 - val_accuracy: 0.2000 - val_loss: 41.5305
# Epoch 27/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9928 - loss: 0.0166 - val_accuracy: 0.2635 - val_loss: 27.6885
# Epoch 28/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9928 - loss: 0.0341 - val_accuracy: 0.2207 - val_loss: 25.3483
# Epoch 29/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9908 - loss: 0.0260 - val_accuracy: 0.2261 - val_loss: 29.3014
# Epoch 30/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9936 - loss: 0.0209 - val_accuracy: 0.3237 - val_loss: 27.1714
# Epoch 31/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9983 - loss: 0.0044 - val_accuracy: 0.3599 - val_loss: 29.7515
# Epoch 32/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.
200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9997 - loss: 5.5766e-04 - val_accuracy: 0.2415 - val_loss: 55.3132
# Epoch 196/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 1.4565e-04 - val_accuracy: 0.2448 - val_loss: 56.0857
# Epoch 197/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 6.0496e-05 - val_accuracy: 0.2415 - val_loss: 56.1522
# Epoch 198/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9986 - loss: 0.0059 - val_accuracy: 0.2589 - val_loss: 53.2718
# Epoch 199/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9955 - loss: 0.0203 - val_accuracy: 0.2562 - val_loss: 61.5073
# Epoch 200/200
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9972 - loss: 0.0102 - val_accuracy: 0.2114 - val_loss: 49.0752

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn_spec.evaluate(X_test_spec, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
threshold = 0.5  # set the threshold value
y_pred_prob = model_cnn_spec.predict(X_test_spec)  # generate prediction probabilities
y_pred = (y_pred_prob > threshold).astype(int)
# ----------------------------------
# 8️⃣ Plot Learning Curves
# ----------------------------------
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4017 - loss: 42.1785
# Test Loss: 42.1785, Test Accuracy: 40.17%
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ======================================================
# 🔹 1️⃣ Validation Set
# ======================================================
print("=== Confusion Matrix : Validation Set ===")

# Predict labels on validation set
y_val_pred_probs = model_cnn_spec.predict(X_val_spec)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

# Compute confusion matrix
cm_val = confusion_matrix(y_val_true, y_val_pred, labels=range(num_classes))

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm_val, annot=True, fmt="d", cmap="Greens",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Validation Set")
plt.show()

# Print classification report
print(classification_report(y_val_true, y_val_pred,
                            labels=range(num_classes),
                            target_names=encoder.classes_))

val_acc = np.mean(y_val_pred == y_val_true)
print(f"✅ Validation Accuracy: {val_acc * 100:.2f}%\n")


# ======================================================
# 🔹 2️⃣ Test Set
# ======================================================
print("=== Confusion Matrix : Test Set ===")

# Predict labels on test set
y_test_pred_probs = model_cnn_spec.predict(X_test_spec)
y_test_pred = np.argmax(y_test_pred_probs, axis=1)
y_test_true = np.argmax(y_test_cat, axis=1)

# Compute confusion matrix
cm_test = confusion_matrix(y_test_true, y_test_pred, labels=range(num_classes))

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.show()

# Print classification report
print(classification_report(y_test_true, y_test_pred,
                            labels=range(num_classes),
                            target_names=encoder.classes_))

test_acc = np.mean(y_test_pred == y_test_true)
print(f"✅ Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# === Confusion Matrix : Validation Set ===
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00       299
#  Sleep stage N2       0.00      0.00      0.00       299
#  Sleep stage N3       0.33      0.00      0.01       299
#   Sleep stage R       0.37      0.08      0.14       299
#   Sleep stage W       0.29      0.97      0.45       299
#
#        accuracy                           0.21      1495
#       macro avg       0.20      0.21      0.12      1495
#    weighted avg       0.20      0.21      0.12      1495
#
# ✅ Validation Accuracy: 21.14%
#
# === Confusion Matrix : Test Set ===
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00       359
#  Sleep stage N2       0.42      1.00      0.60       359
#  Sleep stage N3       0.69      0.21      0.32       359
#   Sleep stage R       1.00      0.80      0.89       359
#   Sleep stage W       0.00      0.00      0.00       359
#
#        accuracy                           0.40      1795
#       macro avg       0.42      0.40      0.36      1795
#    weighted avg       0.42      0.40      0.36      1795
#
# ✅ Test Accuracy: 40.17%
