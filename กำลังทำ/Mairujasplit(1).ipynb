# %%
import mne
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from keras.models import Sequential
from keras.layers import LSTM, Dense,Dropout,TimeDistributed,GlobalAveragePooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from sklearn.model_selection import StratifiedShuffleSplit
from imblearn.over_sampling import SMOTE

# %%
# โหลดข้อมูล
df = pd.read_csv("C:\\Users\\ADMIN\Project\\.venv\\Sleep testFiltered_EEG_Data1.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\2419121426.py:2: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("C:\\Users\\ADMIN\Project\\.venv\\Sleep testFiltered_EEG_Data1.csv")

# %%
channel_map = {
    "1": "EEG F4-M1",
    "2": "EEG C4-M1",
    "3": "EEG O2-M1",
    "4": "EEG C3-M2",
    "5": "EMG chin",
    "6": "EOG E1-M2",
    "7": "EOG E2-M2",
    "8": "ECG"
}
# เปลี่ยนชื่อ column ใน DataFrame
df = df.rename(columns=channel_map)

# ตรวจสอบ
print(df.head())
# Out:
#        Time  EEG F4-M1  EEG C4-M1  EEG O2-M1  EEG C3-M2  EMG chin  EOG E1-M2  \
# 0  0.000000  -0.332139   1.460207  -0.082405   0.945965 -0.556532   8.282122
# 1  0.003906   0.455678  -0.506964  -8.182390   2.241613  3.137224  18.753385
# 2  0.007812  -0.995135  -3.805043 -15.517629   2.785924  5.121238  26.958536
# 3  0.011719  -5.017469  -7.255061 -18.758616   1.417463  5.081020  29.945681
# 4  0.015625 -10.258652  -9.017413 -16.288979  -2.295541  4.092776  27.027844
#
#    EOG E2-M2        ECG      Annotation
# 0  -6.846270 -36.322502   Sleep stage W
# 1  -6.397049 -36.334116   Sleep stage W
# 2  -7.204251 -37.603388   Sleep stage W
# 3  -9.951360 -42.065282   Sleep stage W
# 4 -13.573874 -50.681696   Sleep stage W

# %%
data = df.drop(['Annotation','Time'], axis=1)
labels = df['Annotation']

# %%
N2,W,R,N1,N3=labels.value_counts()
print(N2+W+R+N1+N3)
print(labels.value_counts())
# Out:
# 6558720
# Annotation
# Sleep stage N2    3302400
# Sleep stage W     1159680
# Sleep stage R     1082880
# Sleep stage N1     837120
# Sleep stage N3     176640
# Name: count, dtype: int64

# %% [markdown]
# ## Dugon arnon

# %%
def get_segments(labels):
    """Return list of (start_idx, end_idx, label) for continuous segments"""
    segments = []
    start = 0
    current_label = labels[0]

    for i in range(1, len(labels)):
        if labels[i] != current_label:
            segments.append((start, i, current_label))
            start = i
            current_label = labels[i]

    segments.append((start, len(labels), current_label))
    return segments
segments = get_segments(labels)

valid_segments = [seg for seg in segments if (seg[1] - seg[0]) >= 256]
seg_df = pd.DataFrame(valid_segments, columns=['start', 'end', 'Annotation'])
seg_df["length"] = seg_df["end"] - seg_df["start"]

# %%
seg_df
# Out:
#       start      end       Annotation  length
# 0         0    61440    Sleep stage W   61440
# 1     61440   122880   Sleep stage N1   61440
# 2    122880   130560   Sleep stage N2    7680
# 3    130560   138240   Sleep stage N1    7680
# 4    138240   184320   Sleep stage N2   46080
# ..      ...      ...              ...     ...
# 94  5967360  5982720   Sleep stage N1   15360
# 95  5982720  6120960    Sleep stage W  138240
# 96  6120960  6159360   Sleep stage N1   38400
# 97  6159360  6481920   Sleep stage N2  322560
# 98  6481920  6558720    Sleep stage W   76800
#
# [99 rows x 4 columns]

# %%
seg_df_n3 = seg_df[seg_df['Annotation'] == ' Sleep stage N3']
print(seg_df_n3)
# Out:
#       start      end       Annotation  length
# 15   806400   821760   Sleep stage N3   15360
# 17   829440   844800   Sleep stage N3   15360
# 19   852480   898560   Sleep stage N3   46080
# 21   906240   921600   Sleep stage N3   15360
# 23   929280   936960   Sleep stage N3    7680
# 64  3571200  3609600   Sleep stage N3   38400
# 76  4945920  4976640   Sleep stage N3   30720
# 78  4984320  4992000   Sleep stage N3    7680

# %%
seg_df_R = seg_df[seg_df['Annotation'] == ' Sleep stage R']
print(seg_df_R)
# Out:
#       start      end      Annotation  length
# 31  1190400  1328640   Sleep stage R  138240
# 33  1336320  1382400   Sleep stage R   46080
# 49  2403840  2411520   Sleep stage R    7680
# 51  2419200  2426880   Sleep stage R    7680
# 70  3978240  4193280   Sleep stage R  215040
# 72  4200960  4416000   Sleep stage R  215040
# 83  5299200  5306880   Sleep stage R    7680
# 85  5345280  5790720   Sleep stage R  445440

# %%
seg_df_W = seg_df[seg_df['Annotation'] == ' Sleep stage W']
print(seg_df_W)
# Out:
#       start      end      Annotation  length
# 0         0    61440   Sleep stage W   61440
# 6    199680   207360   Sleep stage W    7680
# 10   268800   299520   Sleep stage W   30720
# 34  1382400  1474560   Sleep stage W   92160
# 40  1896960  1904640   Sleep stage W    7680
# 53  2434560  3079680   Sleep stage W  645120
# 55  3087360  3095040   Sleep stage W    7680
# 57  3102720  3118080   Sleep stage W   15360
# 73  4416000  4454400   Sleep stage W   38400
# 80  5007360  5030400   Sleep stage W   23040
# 87  5798400  5806080   Sleep stage W    7680
# 93  5959680  5967360   Sleep stage W    7680
# 95  5982720  6120960   Sleep stage W  138240
# 98  6481920  6558720   Sleep stage W   76800

# %%
seg_df_N1 = seg_df[seg_df['Annotation'] == ' Sleep stage N1']
print(seg_df_W)
# Out:
#       start      end      Annotation  length
# 0         0    61440   Sleep stage W   61440
# 6    199680   207360   Sleep stage W    7680
# 10   268800   299520   Sleep stage W   30720
# 34  1382400  1474560   Sleep stage W   92160
# 40  1896960  1904640   Sleep stage W    7680
# 53  2434560  3079680   Sleep stage W  645120
# 55  3087360  3095040   Sleep stage W    7680
# 57  3102720  3118080   Sleep stage W   15360
# 73  4416000  4454400   Sleep stage W   38400
# 80  5007360  5030400   Sleep stage W   23040
# 87  5798400  5806080   Sleep stage W    7680
# 93  5959680  5967360   Sleep stage W    7680
# 95  5982720  6120960   Sleep stage W  138240
# 98  6481920  6558720   Sleep stage W   76800

# %%
seg_df_N2 = seg_df[seg_df['Annotation'] == ' Sleep stage N2']
print(seg_df_N2)
# Out:
#       start      end       Annotation  length
# 2    122880   130560   Sleep stage N2    7680
# 4    138240   184320   Sleep stage N2   46080
# 8    253440   261120   Sleep stage N2    7680
# 12   391680   629760   Sleep stage N2  238080
# 14   637440   806400   Sleep stage N2  168960
# 16   821760   829440   Sleep stage N2    7680
# 18   844800   852480   Sleep stage N2    7680
# 20   898560   906240   Sleep stage N2    7680
# 22   921600   929280   Sleep stage N2    7680
# 24   936960  1075200   Sleep stage N2  138240
# 26  1082880  1136640   Sleep stage N2   53760
# 28  1144320  1175040   Sleep stage N2   30720
# 30  1182720  1190400   Sleep stage N2    7680
# 36  1520640  1551360   Sleep stage N2   30720
# 38  1566720  1843200   Sleep stage N2  276480
# 42  1943040  2127360   Sleep stage N2  184320
# 44  2135040  2211840   Sleep stage N2   76800
# 46  2219520  2304000   Sleep stage N2   84480
# 48  2311680  2403840   Sleep stage N2   92160
# 50  2411520  2419200   Sleep stage N2    7680
# 59  3179520  3287040   Sleep stage N2  107520
# 61  3294720  3386880   Sleep stage N2   92160
# 63  3394560  3571200   Sleep stage N2  176640
# 65  3609600  3663360   Sleep stage N2   53760
# 67  3671040  3878400   Sleep stage N2  207360
# 69  3886080  3978240   Sleep stage N2   92160
# 75  4546560  4945920   Sleep stage N2  399360
# 77  4976640  4984320   Sleep stage N2    7680
# 79  4992000  5007360   Sleep stage N2   15360
# 82  5038080  5299200   Sleep stage N2  261120
# 89  5859840  5928960   Sleep stage N2   69120
# 91  5936640  5952000   Sleep stage N2   15360
# 97  6159360  6481920   Sleep stage N2  322560

# %%
seg_counts = seg_df['Annotation'].value_counts()
print(seg_counts)
# Out:
# Annotation
# Sleep stage N1    36
# Sleep stage N2    33
# Sleep stage W     14
# Sleep stage N3     8
# Sleep stage R      8
# Name: count, dtype: int64

# %% [markdown]
# ## Select data

# %% [markdown]
# ### train set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_train = seg_df[
#     (
#         ((seg_df['start'] >= 806400) & (seg_df['end'] <= 821760)) |
#         ((seg_df['start'] >= 829440) & (seg_df['end'] <= 844800)) |
#         ((seg_df['start'] >= 852480) & (seg_df['end'] <= 898560)) |
#         ((seg_df['start'] >= 906240) & (seg_df['end'] <= 921600))
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_train = seg_df.loc[[15, 17, 19, 21]]

# %%
# selected_r_train = seg_df[
#     (
#         ((seg_df['start'] >= 3978240) & (seg_df['end'] <= 4070400)) #70
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
# ดึง row ที่ index = 31
r_seg = seg_df.loc[31]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_r_seg = pd.DataFrame([{
    'start': r_seg['start'],
    'end': r_seg['start'] + 92160,
    'Annotation': r_seg['Annotation'],
    'length': 92160
}])
selected_r_train = pd.concat([partial_r_seg], ignore_index=True)

# %%
selected_r_train
# Out:
#      start      end      Annotation  length
# 0  1190400  1282560   Sleep stage R   92160

# %%
# selected_w_train = seg_df[
#     (
#         ((seg_df['start'] >= 1382400) & (seg_df['end'] <= 1474560)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
w_seg = seg_df.loc[53]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_w_seg = pd.DataFrame([{
    'start': w_seg['end'] - 92160,        # เริ่มจากท้ายสุดย้อนมา 92160 ตัว
    'end': w_seg['end'],                  # จบที่ท้าย segment
    'Annotation': w_seg['Annotation'],
    'length': 92160
}])
selected_w_train = pd.concat([partial_w_seg], ignore_index=True)

# %%
selected_n1_train = pd.concat([
    seg_df.loc[[1]],  # iloc[1] ทั้งอัน
    pd.DataFrame([{
        'start': seg_df.loc[7, 'start'],
        'end': seg_df.loc[7, 'start'] + min(30720, seg_df.loc[7, 'length']),
        'Annotation': seg_df.loc[7, 'Annotation'],
        'length': min(30720, seg_df.loc[7, 'length'])
    }])
], ignore_index=True)

# %%
# selected_n2_train = seg_df[
#     (
#         ((seg_df['start'] >= 2311680) & (seg_df['end'] <= 2403840)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
selected_n2_train = seg_df.loc[[48]]

# %%
for name, df in {
    "N1": selected_n1_train,
    "N2": selected_n2_train,
    "N3": selected_n3_train,
    "R": selected_r_train,
    "W": selected_w_train
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 2 segments
# N2: 1 segments
# N3: 4 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Test set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_test = seg_df[
#     (
#         ((seg_df['start'] >= 929280) & (seg_df['end'] <= 936960)) |
#         ((seg_df['start'] >= 3571200) & (seg_df['end'] <= 3609600)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_test = seg_df.loc[[23,64]]

# %%
# selected_r_test = seg_df[
#     (
#         ((seg_df['start'] >= 1336320) & (seg_df['end'] <= 1382400)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
r_seg_test = seg_df.loc[70]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_r_seg = pd.DataFrame([{
    'start': r_seg_test['start'],
    'end': r_seg_test['start'] + 46080,
    'Annotation': r_seg_test['Annotation'],
    'length': 46080
}])
selected_r_test = pd.concat([partial_r_seg], ignore_index=True)

# %%
# selected_w_test = seg_df[
#     (
#         ((seg_df['start'] >= 0) & (seg_df['end'] <= 46080)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
w_seg_test = seg_df.loc[0]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_w_seg = pd.DataFrame([{
    'start': w_seg_test['start'],
    'end': w_seg_test['start'] + 46080,
    'Annotation': w_seg_test['Annotation'],
    'length': 46080
}])
selected_w_test = pd.concat([partial_w_seg], ignore_index=True)

# %%
# selected_n1_test = seg_df[
#     (
#         ((seg_df['start'] >= 1474560) & (seg_df['end'] <= 41520640)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N1')
# ]
selected_n1_test = seg_df.loc[[35]]

# %%
# selected_n2_test = seg_df[
#     (
#         ((seg_df['start'] >= 138240) & (seg_df['end'] <= 184320)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
n2_seg_test = seg_df.loc[12]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_n2_seg = pd.DataFrame([{
    'start': n2_seg_test['start'],
    'end': n2_seg_test['start'] + 46080,
    'Annotation': n2_seg_test['Annotation'],
    'length': 46080
}])
selected_n2_test = pd.concat([partial_n2_seg], ignore_index=True)

# %%
for name, df in {
    "N1": selected_n1_test,
    "N2": selected_n2_test,
    "N3": selected_n3_test,
    "R": selected_r_test,
    "W": selected_w_test
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 1 segments
# N2: 1 segments
# N3: 2 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Validate set

# %%
##ตัวนี้มีน้อย เอาตัวนี้เป็นเบส
# selected_n3_val = seg_df[
#     (
#         ((seg_df['start'] >= 4945920) & (seg_df['end'] <= 4976640)) |
#         ((seg_df['start'] >= 4984320) & (seg_df['end'] <= 4992000)) 
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N3')
# ]
selected_n3_val = seg_df.loc[[76,78]]

# %%
# selected_r_val = seg_df[
#     (
#         ((seg_df['start'] >= 5345280) & (seg_df['end'] <= 5383680)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage R')
# ]
r_seg_val = seg_df.loc[33]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_r_segval = pd.DataFrame([{
    'start': r_seg_val['start'],
    'end': r_seg_val['start'] + 38400,
    'Annotation': r_seg_val['Annotation'],
    'length': 38400
}])
selected_r_val = pd.concat([partial_r_segval], ignore_index=True)

# %%
# selected_w_val = seg_df[
#     (
#         ((seg_df['start'] >= 4416000) & (seg_df['end'] <= 4454400)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage W')
# ]
w_seg_val = seg_df.loc[34]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_w_seg_val = pd.DataFrame([{
    'start': w_seg_val['end'] - 38400,        # เริ่มจากท้ายสุดย้อนมา 92160 ตัว
    'end': w_seg_val['end'],                  # จบที่ท้าย segment
    'Annotation': w_seg_val['Annotation'],
    'length': 92160
}])
selected_w_val = pd.concat([partial_w_seg_val], ignore_index=True)

# %%
# selected_n1_val = seg_df[
#     (
#         ((seg_df['start'] >= 1904640) & (seg_df['end'] <= 1943040)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N1')
# ]
selected_n1_val = seg_df.loc[[41]]

# %%
# selected_n2_val = seg_df[
#     (
#         ((seg_df['start'] >= 5859840) & (seg_df['end'] <= 5898240)) 
         
        
#     )
#     & (seg_df['Annotation'] == ' Sleep stage N2')
# ]
n2_seg_val = seg_df.loc[38]

# ตัดเฉพาะ 92160 sample แรกของช่วงนี้
partial_n2_segval = pd.DataFrame([{
    'start': n2_seg_val['start'],
    'end': n2_seg_val['start'] + 38400,
    'Annotation': n2_seg_val['Annotation'],
    'length': 38400
}])
selected_n2_val = pd.concat([partial_n2_segval], ignore_index=True)

# %%
for name, df in {
    "N1": selected_n1_val,
    "N2": selected_n2_val,
    "N3": selected_n3_val,
    "R": selected_r_val,
    "W": selected_w_val
}.items():
    print(f"{name}: {len(df)} segments")
# Out:
# N1: 1 segments
# N2: 1 segments
# N3: 2 segments
# R: 1 segments
# W: 1 segments

# %% [markdown]
# ### Train/Test/Val Split(manual balanced sampling)

# %%
# รวม segment ของ train/test/val แต่ละคลาส
train_segments = pd.concat([
    selected_n3_train,
    selected_r_train,
    selected_w_train,
    selected_n1_train,
    selected_n2_train
], ignore_index=True)

test_segments = pd.concat([
    selected_n3_test,
    selected_r_test,
    selected_w_test,
    selected_n1_test,
    selected_n2_test
], ignore_index=True)

val_segments = pd.concat([
    selected_n3_val,
    selected_r_val,
    selected_w_val,
    selected_n1_val,
    selected_n2_val
], ignore_index=True)

# %%
train_segments
# Out:
#      start      end       Annotation  length
# 0   806400   821760   Sleep stage N3   15360
# 1   829440   844800   Sleep stage N3   15360
# 2   852480   898560   Sleep stage N3   46080
# 3   906240   921600   Sleep stage N3   15360
# 4  1190400  1282560    Sleep stage R   92160
# 5  2987520  3079680    Sleep stage W   92160
# 6    61440   122880   Sleep stage N1   61440
# 7   207360   238080   Sleep stage N1   30720
# 8  2311680  2403840   Sleep stage N2   92160

# %%
test_segments
# Out:
#      start      end       Annotation  length
# 0   929280   936960   Sleep stage N3    7680
# 1  3571200  3609600   Sleep stage N3   38400
# 2  3978240  4024320    Sleep stage R   46080
# 3        0    46080    Sleep stage W   46080
# 4  1474560  1520640   Sleep stage N1   46080
# 5   391680   437760   Sleep stage N2   46080

# %%
val_segments
# Out:
#      start      end       Annotation  length
# 0  4945920  4976640   Sleep stage N3   30720
# 1  4984320  4992000   Sleep stage N3    7680
# 2  1336320  1374720    Sleep stage R   38400
# 3  1436160  1474560    Sleep stage W   92160
# 4  1904640  1943040   Sleep stage N1   38400
# 5  1566720  1605120   Sleep stage N2   38400

# %%
X_train_df = pd.concat([data.iloc[row.start:row.end] for _, row in train_segments.iterrows()]).reset_index(drop=True)
y_train_df = pd.concat([labels.iloc[row.start:row.end] for _, row in train_segments.iterrows()]).reset_index(drop=True)

X_test_df = pd.concat([data.iloc[row.start:row.end] for _, row in test_segments.iterrows()]).reset_index(drop=True)
y_test_df = pd.concat([labels.iloc[row.start:row.end] for _, row in test_segments.iterrows()]).reset_index(drop=True)

X_val_df = pd.concat([data.iloc[row.start:row.end] for _, row in val_segments.iterrows()]).reset_index(drop=True)
y_val_df = pd.concat([labels.iloc[row.start:row.end] for _, row in val_segments.iterrows()]).reset_index(drop=True)

# %%
X_train_df
# Out:
#         EEG F4-M1  EEG C4-M1  EEG O2-M1  EEG C3-M2  EMG chin  EOG E1-M2  \
# 0       11.988918  -9.800350   1.234130  -8.155535 -1.003727   0.444482
# 1       11.834525  -9.043753   3.469183  -6.757648 -1.875438   2.316137
# 2       10.006894 -11.314823   0.585498  -7.182482 -2.514637   2.795853
# 3        6.896737 -15.782217  -4.765642  -8.420605 -3.129654   3.601841
# 4        3.681137 -19.279838  -8.307767  -7.698028 -3.579161   5.977823
# ...           ...        ...        ...        ...       ...        ...
# 460795  -3.685817   3.478153   8.385379  -1.021841  3.023808 -12.887457
# 460796  -6.792157  -0.521728   2.413528  -3.069949  2.714382 -11.688400
# 460797  -8.702654  -1.252788   2.894249  -1.468036  2.174243  -7.976751
# 460798  -8.545341   2.253638   8.401847   3.189460  1.729178  -4.168177
# 460799  -8.086442   5.267957  11.459320   5.939815  1.141949  -2.707327
#
#         EOG E2-M2         ECG
# 0       -9.096484  126.184752
# 1       -7.901541  148.202564
# 2       -7.022960  178.106566
# 3       -5.600389  236.319262
# 4       -3.770041  328.201888
# ...           ...         ...
# 460795   2.401130   38.065769
# 460796   3.340073   36.101996
# 460797   5.085803   39.676452
# 460798   5.454691   48.016811
# 460799   3.850731   54.435447
#
# [460800 rows x 8 columns]

# %%
plt.figure(figsize=(13, 4))

# กำหนด offset สำหรับแต่ละชุด
offset_train = 0
offset_val = len(X_train_df)
offset_test = len(X_train_df) + len(X_val_df)

plt.plot(np.arange(offset_train, offset_train + len(X_train_df)),
         X_train_df['EEG C4-M1'], label='Training Set')

plt.plot(np.arange(offset_val, offset_val + len(X_val_df)),
         X_val_df['EEG C4-M1'], label='Validation Set')

plt.plot(np.arange(offset_test, offset_test + len(X_test_df)),
         X_test_df['EEG C4-M1'], label='Test Set')
plt.axvline(len(X_train_df), color='gray', linestyle='--')
plt.axvline(len(X_train_df) + len(X_val_df), color='gray', linestyle='--')

plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.title("EEG Signal (Channel C4-M1) split into Training, Validation, and Test Sets")
plt.xlabel("Time (samples)")
plt.ylabel("Amplitude")
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG C4-M1)
plt.plot(X_train_df.index, X_train_df['EEG C4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage W'],          # index ของ W
    X_train_df['EEG C4-M1'][y_train_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage N3'],          # index ของ W
    X_train_df['EEG C4-M1'][y_train_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage N1'],          # index ของ W
    X_train_df['EEG C4-M1'][y_train_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_train_df.index[y_train_df == ' Sleep stage R'],          # index ของ W
    X_train_df['EEG C4-M1'][y_train_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Training set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG C4-M1)
plt.plot(X_test_df.index, X_test_df['EEG C4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage W'],          # index ของ W
    X_test_df['EEG C4-M1'][y_test_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage N3'],          # index ของ W
    X_test_df['EEG C4-M1'][y_test_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage N1'],          # index ของ W
    X_test_df['EEG C4-M1'][y_test_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_test_df.index[y_test_df == ' Sleep stage R'],          # index ของ W
    X_test_df['EEG C4-M1'][y_test_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Test set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
plt.figure(figsize=(13, 4))

# plot สัญญาณ EEG ทั้งหมด (เช่น channel EEG C4-M1)
plt.plot(X_val_df.index, X_val_df['EEG C4-M1'], color='gray', label='EEG Signal')

# plot จุดที่เป็น sleep stage W
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage W'],          # index ของ W
    X_val_df['EEG C4-M1'][y_val_df == ' Sleep stage W'],   # ค่าของ channel
    c='orange',
    label='Sleep stage W',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage N3'],          # index ของ W
    X_val_df['EEG C4-M1'][y_val_df == ' Sleep stage N3'],   # ค่าของ channel
    c='red',
    label='Sleep stage N3',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage N1'],          # index ของ W
    X_val_df['EEG C4-M1'][y_val_df == ' Sleep stage N1'],   # ค่าของ channel
    c='green',
    label='Sleep stage N1',
    s=50,
    marker='o'
)
plt.scatter(
    X_val_df.index[y_val_df == ' Sleep stage R'],          # index ของ W
    X_val_df['EEG C4-M1'][y_val_df == ' Sleep stage R'],   # ค่าของ channel
    c='purple',
    label='Sleep stage R',
    s=50,
    marker='o'
)
plt.title("EEG Signal (Validate set) ")
plt.xlabel("Samples")
plt.ylabel("Amplitude (µV)")
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)
plt.show()

# %%
print("Train class distribution (%):")
print(y_train_df.value_counts(normalize=True) * 100)

print("\nTest class distribution (%):")
print(y_test_df.value_counts(normalize=True) * 100)

print("\nValidation class distribution (%):")
print(y_val_df.value_counts(normalize=True) * 100)
# Out:
# Train class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64
#
# Test class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64
#
# Validation class distribution (%):
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64

# %%
y_train_df.value_counts(), y_val_df.value_counts(), y_test_df.value_counts()
# Out:
# (Annotation
#  Sleep stage N3    92160
#  Sleep stage R     92160
#  Sleep stage W     92160
#  Sleep stage N1    92160
#  Sleep stage N2    92160
#  Name: count, dtype: int64,
#  Annotation
#  Sleep stage N3    38400
#  Sleep stage R     38400
#  Sleep stage W     38400
#  Sleep stage N1    38400
#  Sleep stage N2    38400
#  Name: count, dtype: int64,
#  Annotation
#  Sleep stage N3    46080
#  Sleep stage R     46080
#  Sleep stage W     46080
#  Sleep stage N1    46080
#  Sleep stage N2    46080
#  Name: count, dtype: int64)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch


# -----------------------------
# ⚙️ ตั้งค่าพื้นฐาน
# -----------------------------
fs = 256  # sampling rate (Hz)
channel_name = "EEG F4-M1"

# กลุ่มที่จะแสดง
group1 = [' Sleep stage W', ' Sleep stage N2']
group2 = [' Sleep stage N1', ' Sleep stage N2', ' Sleep stage N3']

# -----------------------------
# 🧠 กำหนดย่านความถี่สมอง (Hz)
# -----------------------------
bands = {
    "Delta (0.5–4)": (0.5, 4),
    "Theta (4–8)": (4, 8),
    "Alpha (8–12)": (8, 12),
    "Beta (12–30)": (12, 30),
    "Gamma (30–45)": (30, 45)
}

# -----------------------------
# 🎨 สร้าง Subplots
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(15, 5), sharey=True)

# -----------------------------------
# ฟังก์ชันช่วย: แสดงเส้นย่านความถี่
# -----------------------------------
def plot_band_lines(ax):
    ylim = ax.get_ylim()
    for label, (f_start, f_end) in bands.items():
        # เส้นแนวดิ่งและแถบสีจาง
        ax.axvline(f_start, color='gray', linestyle='--', alpha=0.3)
        ax.axvline(f_end, color='gray', linestyle='--', alpha=0.3)
        ax.axvspan(f_start, f_end, color='gray', alpha=0.05)
        # ใส่ชื่อย่าน (เช่น Delta, Theta, ...)
        ax.text((f_start + f_end)/2, ylim[1]*0.7, label.split()[0],
                ha='center', va='center', fontsize=9, color='dimgray')

# -----------------------------
# 🔹 ซ้าย: W และ N2
# -----------------------------
for stage in group1:
    mask = (y_train_df == stage).values.flatten()
    signal = X_train_df.loc[mask, channel_name].values

    if len(signal) < fs * 2:
        print(f"⚠️ {stage.strip()} มีข้อมูลไม่เพียงพอ (len={len(signal)})")
        continue

    f, psd = welch(signal, fs=fs, nperseg=fs*2)
    axes[0].semilogy(f, psd, label=stage.strip())

axes[0].set_xlim(0, 60)
axes[0].set_title("PSD - Sleep stages W & N2")
axes[0].set_xlabel("Frequency (Hz)")
axes[0].set_ylabel("Power Spectral Density (V²/Hz)")
axes[0].legend()
axes[0].grid(True, alpha=0.3)
plot_band_lines(axes[0])

# -----------------------------
# 🔹 ขวา: N1, N2, N3
# -----------------------------
for stage in group2:
    mask = (y_train_df == stage).values.flatten()
    signal = X_train_df.loc[mask, channel_name].values

    if len(signal) < fs * 2:
        print(f"⚠️ {stage.strip()} มีข้อมูลไม่เพียงพอ (len={len(signal)})")
        continue

    f, psd = welch(signal, fs=fs, nperseg=fs*2)
    axes[1].semilogy(f, psd, label=stage.strip())

axes[1].set_xlim(0, 60)
axes[1].set_title("PSD - Sleep stages N1, N2, N3")
axes[1].set_xlabel("Frequency (Hz)")
axes[1].legend()
axes[1].grid(True, alpha=0.3)
plot_band_lines(axes[1])

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch


# -----------------------------
# ⚙️ ตั้งค่าพื้นฐาน
# -----------------------------
fs = 256  # sampling rate
channel_name = "EEG F4-M1"

# กลุ่ม stage
group1 = [' Sleep stage W', ' Sleep stage N2']
group2 = [' Sleep stage N1', ' Sleep stage N2', ' Sleep stage N3']

# -----------------------------
# 🧠 ย่านความถี่สมอง (Hz)
# -----------------------------
bands = {
    "Delta (0.5–4)": (0.5, 4),
    "Theta (4–8)": (4, 8),
    "Alpha (8–12)": (8, 12),
    "Beta (12–30)": (12, 30),
    "Gamma (30–45)": (30, 45)
}

# -----------------------------
# 🎨 ฟังก์ชันช่วย: แสดงย่านความถี่ในกราฟ
# -----------------------------
def plot_band_lines(ax):
    ylim = ax.get_ylim()
    for label, (f_start, f_end) in bands.items():
        ax.axvspan(f_start, f_end, color='gray', alpha=0.05)
        ax.axvline(f_start, color='gray', linestyle='--', alpha=0.4)
        ax.axvline(f_end, color='gray', linestyle='--', alpha=0.4)
        # เขียนชื่อย่านไว้ตรงกลาง (ด้านบน)
        ax.text((f_start + f_end)/2, ylim[1]*0.6, label.split()[0],
                ha='center', va='center', fontsize=9, color='dimgray')

# -----------------------------
# ⚙️ ฟังก์ชันสำหรับพล็อต PSD
# -----------------------------
def plot_psd_by_stage(X_df, y_df, title_prefix="Dataset"):
    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

    # ----- ซ้าย: W, N2 -----
    for stage in group1:
        mask = (y_df == stage).values.flatten()
        signal = X_df.loc[mask, channel_name].values

        if len(signal) < fs * 2:
            print(f"⚠️ {stage.strip()} ({title_prefix}) มีข้อมูลไม่เพียงพอ (len={len(signal)})")
            continue

        f, psd = welch(signal, fs=fs, nperseg=fs*2)
        axes[0].semilogy(f, psd, label=stage.strip())

    axes[0].set_xlim(0, 60)
    axes[0].set_title(f"{title_prefix}: PSD - W & N2")
    axes[0].set_xlabel("Frequency (Hz)")
    axes[0].set_ylabel("Power Spectral Density (V²/Hz)")
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    plot_band_lines(axes[0])

    # ----- ขวา: N1, N2, N3 -----
    for stage in group2:
        mask = (y_df == stage).values.flatten()
        signal = X_df.loc[mask, channel_name].values

        if len(signal) < fs * 2:
            print(f"⚠️ {stage.strip()} ({title_prefix}) มีข้อมูลไม่เพียงพอ (len={len(signal)})")
            continue

        f, psd = welch(signal, fs=fs, nperseg=fs*2)
        axes[1].semilogy(f, psd, label=stage.strip())

    axes[1].set_xlim(0, 60)
    axes[1].set_title(f"{title_prefix}: PSD - N1, N2, N3")
    axes[1].set_xlabel("Frequency (Hz)")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    plot_band_lines(axes[1])

    plt.tight_layout()
    plt.show()

# -----------------------------
# 📊 เรียกใช้สำหรับ Test และ Validation set
# -----------------------------
plot_psd_by_stage(X_test_df, y_test_df, title_prefix="Test Set")
plot_psd_by_stage(X_val_df, y_val_df, title_prefix="Validation Set")

# %% [markdown]
# ## Normalize

# %%
mean = X_train_df.mean()
std = X_train_df.std()

X_train_df = (X_train_df - mean) / std
X_val_df   = (X_val_df   - mean) / std
X_test_df  = (X_test_df  - mean) / std

# %% [markdown]
# ### Select Channel

# %%
X_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460800 entries, 0 to 460799
# Data columns (total 8 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   EEG F4-M1  460800 non-null  float64
#  1   EEG C4-M1  460800 non-null  float64
#  2   EEG O2-M1  460800 non-null  float64
#  3   EEG C3-M2  460800 non-null  float64
#  4   EMG chin   460800 non-null  float64
#  5   EOG E1-M2  460800 non-null  float64
#  6   EOG E2-M2  460800 non-null  float64
#  7   ECG        460800 non-null  float64
# dtypes: float64(8)
# memory usage: 28.1 MB

# %%
selected_channels = ['EEG F4-M1', 'EEG C4-M1', 'EEG O2-M1','EEG C3-M2']

# Create the new DataFrame with only the selected channels
X_train_df_reduced = X_train_df[selected_channels]
X_val_df_reduced = X_val_df[selected_channels]
X_test_df_reduced = X_test_df[selected_channels]

X_train_df_reduced.shape, X_val_df_reduced.shape, X_test_df_reduced.shape
# Out:
# ((460800, 4), (192000, 4), (230400, 4))

# %% [markdown]
# ### Create Sliding Window

# %%
def apply_sliding_window(data, label, window_size, step_size):
    # Reset index เพื่อให้ iloc ทำงานได้แน่นอน
    data = data.reset_index(drop=True)
    label = label.reset_index(drop=True)

    window_data = []
    window_label = []

    for i in range(0, len(data) - window_size + 1, step_size):
        window = data.iloc[i:i + window_size]
        label_slice = label.iloc[i:i + window_size]

        # ตรวจว่าทั้ง window มี label เดียวกันไหม
        unique_labels = label_slice.unique()
        if len(unique_labels) == 1:  # ✅ มีคลาสเดียว
            window_data.append(window)
            window_label.append(unique_labels[0])
        else:
            continue  # 🚫 ถ้ามีมากกว่า 1 คลาส -> ข้ามเลย

    X = np.array(window_data)
    y = np.array(window_label)
    return X, y

# %%
# Define parameters
window_size = 1024
step_size = 256

# Apply sliding window function to the train/test set
X_train, y_train =  apply_sliding_window(X_train_df, y_train_df, window_size, step_size)
X_val, y_val =  apply_sliding_window(X_val_df, y_val_df, window_size, step_size)
X_test, y_test = apply_sliding_window(X_test_df, y_test_df, window_size, step_size)

X_train_reduced, y_train_reduced =  apply_sliding_window(X_train_df_reduced, y_train_df, window_size, step_size)
X_val_reduced, y_val_reduced =  apply_sliding_window(X_val_df_reduced, y_val_df, window_size, step_size)
X_test_reduced, y_test_reduced = apply_sliding_window(X_test_df_reduced, y_test_df, window_size, step_size)

print("X_train:" ,X_train.shape, ", y_train:", y_train.shape)
print("X_val:" ,X_val.shape, ", y_val:", y_val.shape)
print("X_test:" ,X_test.shape, ", y_test:", y_test.shape)

print("X_train_reduced:" ,X_train_reduced.shape, ", y_train_reduced:", y_train_reduced.shape)
print("X_val_reduced:" ,X_val_reduced.shape, ", y_val_reduced:", y_val_reduced.shape)
print("X_test_reduced:" ,X_test_reduced.shape, ", y_test_reduced:", y_test_reduced.shape)
# Out:
# X_train: (1785, 1024, 8) , y_train: (1785,)
# X_val: (735, 1024, 8) , y_val: (735,)
# X_test: (885, 1024, 8) , y_test: (885,)
# X_train_reduced: (1785, 1024, 4) , y_train_reduced: (1785,)
# X_val_reduced: (735, 1024, 4) , y_val_reduced: (735,)
# X_test_reduced: (885, 1024, 4) , y_test_reduced: (885,)

# %%
print("Sample (original y_train_df):")
print(y_train_df.value_counts())
print("After Sliding Window (selected channels y_train_reduced):")
print(pd.Series(y_train_reduced).value_counts())
# รวมผลเป็น DataFrame เพื่อเทียบง่าย ๆ
annotation_check = pd.DataFrame({
    "N Sample": y_train_df.value_counts(),
}).fillna(0).astype(int)

print(annotation_check)
annotation_check.plot(kind="bar", figsize=(10, 5))
plt.title("N Sample Train set")
plt.ylabel("Count")
plt.xlabel("Sleep Stage")
plt.xticks(rotation=45)
plt.show()
print(y_train_df.value_counts(normalize=True) * 100)
# Out:
# Sample (original y_train_df):
# Annotation
# Sleep stage N3    92160
# Sleep stage R     92160
# Sleep stage W     92160
# Sleep stage N1    92160
# Sleep stage N2    92160
# Name: count, dtype: int64
# After Sliding Window (selected channels y_train_reduced):
# Sleep stage N3    357
# Sleep stage R     357
# Sleep stage W     357
# Sleep stage N1    357
# Sleep stage N2    357
# Name: count, dtype: int64
#                 N Sample
# Annotation
# Sleep stage N3     92160
# Sleep stage R      92160
# Sleep stage W      92160
# Sleep stage N1     92160
# Sleep stage N2     92160
# Annotation
# Sleep stage N3    20.0
# Sleep stage R     20.0
# Sleep stage W     20.0
# Sleep stage N1    20.0
# Sleep stage N2    20.0
# Name: proportion, dtype: float64

# %%
def clean_X_y(X, y):
    """Remove samples where y is NaN or 'nan' string"""
    # ตัดให้ X, y มีความยาวเท่ากันก่อน
    min_len = min(len(X), len(y))
    X = X[:min_len]
    y = y[:min_len]

    mask = ~(pd.isna(y) | (y == 'nan'))
    X_clean = X[mask]
    y_clean = y[mask]
    return X_clean, y_clean

# --- ลบ NaN และทำให้ขนาดตรงกัน ---
X_train, y_train = clean_X_y(X_train, y_train)
X_val, y_val     = clean_X_y(X_val, y_val)
X_test, y_test   = clean_X_y(X_test, y_test)

print("Shapes after cleaning NaN:")
print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:", X_val.shape, "y_val:", y_val.shape)
print("X_test:", X_test.shape, "y_test:", y_test.shape)
# Out:
# Shapes after cleaning NaN:
# X_train: (1785, 1024, 8) y_train: (1785,)
# X_val: (735, 1024, 8) y_val: (735,)
# X_test: (885, 1024, 8) y_test: (885,)

# %% [markdown]
# ## Train

# %% [markdown]
# ### CNN(4CH)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from sklearn.utils.class_weight import compute_class_weight

# %%
# -----------------------------
# 1. แปลง label เป็นตัวเลข + one-hot
# -----------------------------
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_val_enc   = encoder.transform(y_val)
y_test_enc  = encoder.transform(y_test)

num_classes = len(np.unique(y_train_enc))

y_train_cat = to_categorical(y_train_enc, num_classes=num_classes)
y_val_cat   = to_categorical(y_val_enc, num_classes=num_classes)
y_test_cat  = to_categorical(y_test_enc, num_classes=num_classes)

# -----------------------------
# 2. แปลง X ให้เป็น float32 และ shape = (samples, timesteps, features)
# -----------------------------
X_train = np.array(X_train_reduced, dtype=np.float32)
X_val   = np.array(X_val_reduced, dtype=np.float32)
X_test  = np.array(X_test_reduced, dtype=np.float32)

if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("X_train shape:", X_train.shape)  # (samples, timesteps, channels)
print("y_train shape:", y_train_cat.shape)

# -----------------------------
# 3. สร้าง CNN model
# -----------------------------
model_cnn = Sequential([
    Conv1D(filters=32, kernel_size=7, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=128, kernel_size=3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_cnn.summary()
# Out:
# X_train shape: (895, 1024, 4)
# y_train shape: (895, 5)
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 1018, 32)       │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1018, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 509, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 505, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 505, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 252, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 250, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 250, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 125, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 121, 64)        │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 121, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3840)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       491,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 570,405 (2.18 MB)
#  Trainable params: 569,829 (2.17 MB)
#  Non-trainable params: 576 (2.25 KB)

# %%
# --- Ensure all sets are same length ---
min_train_len = min(len(X_train), len(y_train_cat))
min_val_len   = min(len(X_val), len(y_val_cat))
min_test_len  = min(len(X_test), len(y_test_cat))

X_train = X_train[:min_train_len]
y_train_cat = y_train_cat[:min_train_len]

X_val = X_val[:min_val_len]
y_val_cat = y_val_cat[:min_val_len]

X_test = X_test[:min_test_len]
y_test_cat = y_test_cat[:min_test_len]

print("After sync:")
print("Train:", X_train.shape, y_train_cat.shape)
print("Val:  ", X_val.shape, y_val_cat.shape)
print("Test: ", X_test.shape, y_test_cat.shape)
# Out:
# After sync:
# Train: (895, 1024, 4) (895, 5)
# Val:   (370, 1024, 4) (370, 5)
# Test:  (445, 1024, 4) (445, 5)

# %%
# -----------------------------
# 4. Train CNN model (no early stopping)
# -----------------------------
callbacks = [
    ModelCheckpoint('best_cnn_model.keras', monitor='val_loss', save_best_only=True)
]

history = model_cnn.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=100,
    batch_size=32,
    shuffle=True,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.5140 - loss: 1.5701 - val_accuracy: 0.2027 - val_loss: 5.3610
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7263 - loss: 0.7541 - val_accuracy: 0.2000 - val_loss: 6.4519
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8905 - loss: 0.3465 - val_accuracy: 0.2757 - val_loss: 4.1682
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8883 - loss: 0.2869 - val_accuracy: 0.2649 - val_loss: 4.7480
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9363 - loss: 0.1672 - val_accuracy: 0.2270 - val_loss: 7.8555
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9676 - loss: 0.1001 - val_accuracy: 0.2270 - val_loss: 7.6935
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9832 - loss: 0.0748 - val_accuracy: 0.2270 - val_loss: 8.6808
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9788 - loss: 0.0657 - val_accuracy: 0.2189 - val_loss: 9.8607
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9765 - loss: 0.0747 - val_accuracy: 0.2108 - val_loss: 12.7454
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0339 - val_accuracy: 0.2108 - val_loss: 12.9712
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0274 - val_accuracy: 0.2108 - val_loss: 14.4952
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0256 - val_accuracy: 0.1946 - val_loss: 16.7117
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0246 - val_accuracy: 0.2000 - val_loss: 17.6233
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9877 - loss: 0.0300 - val_accuracy: 0.2108 - val_loss: 19.6416
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9855 - loss: 0.0621 - val_accuracy: 0.2108 - val_loss: 19.8600
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9922 - loss: 0.0223 - val_accuracy: 0.2162 - val_loss: 23.1420
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9855 - loss: 0.0460 - val_accuracy: 0.2108 - val_loss: 21.7181
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9799 - loss: 0.0507 - val_accuracy: 0.2135 - val_loss: 23.9133
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0554 - val_accuracy: 0.2135 - val_loss: 28.0133
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9788 - loss: 0.0615 - val_accuracy: 0.2189 - val_loss: 25.8627
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9877 - loss: 0.0443 - val_accuracy: 0.1946 - val_loss: 29.4576
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0233 - val_accuracy: 0.2189 - val_loss: 32.8283
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9944 - loss: 0.0153 - val_accuracy: 0.2216 - val_loss: 31.2171
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0377 - val_accuracy: 0.2162 - val_loss: 31.5596
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0505 - val_accuracy: 0.2189 - val_loss: 24.6621
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0291 - val_accuracy: 0.2108 - val_loss: 27.5939
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0465 - val_accuracy: 0.2054 - val_loss: 31.1795
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9944 - loss: 0.0166 - val_accuracy: 0.2108 - val_loss: 30.0051
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0247 - val_accuracy: 0.2081 - val_loss: 31.1564
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0197 - val_accuracy: 0.2081 - val_loss: 29.8811
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.2108 - val_loss: 29.0379
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0212 - val_accuracy: 0.2027 - val_loss: 32.4048
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0424 - val_accuracy: 0.2054 - val_loss: 33.1015
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0286 - val_accuracy: 0.2054 - val_loss: 33.1288
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9888 - loss: 0.0415 - val_accuracy: 0.1919 - val_loss: 39.0159
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9765 - loss: 0.0824 - val_accuracy: 0.1838 - val_loss: 34.6413
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9218 - loss: 0.3900 - val_accuracy: 0.2108 - val_loss: 32.7600
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9654 - loss: 0.0960 - val_accuracy: 0.1027 - val_loss: 38.4072
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9654 - loss: 0.1168 - val_accuracy: 0.2081 - val_loss: 32.3360
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9810 - loss: 0.0630 - val_accuracy: 0.2243 - val_loss: 25.8943
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9788 - loss: 0.0840 - val_accuracy: 0.2216 - val_loss: 31.2664
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0294 - val_accuracy: 0.2108 - val_loss: 33.6546
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0199 - val_accuracy: 0.2243 - val_loss: 33.5416
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0066 - val_accuracy: 0.2108 - val_loss: 34.5875
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0080 - val_accuracy: 0.1757 - val_loss: 39.4453
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.1216 - val_loss: 45.6855
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0112 - val_accuracy: 0.1541 - val_loss: 42.4453
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0095 - val_accuracy: 0.1838 - val_loss: 44.2857
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0064 - val_accuracy: 0.2162 - val_loss: 41.2148
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0086 - val_accuracy: 0.2216 - val_loss: 41.8487
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0033 - val_accuracy: 0.2216 - val_loss: 42.1623
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0057 - val_accuracy: 0.2162 - val_loss: 45.0861
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0091 - val_accuracy: 0.1973 - val_loss: 52.2471
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.1919 - val_loss: 57.3126
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0308 - val_accuracy: 0.1784 - val_loss: 57.0516
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0128 - val_accuracy: 0.2054 - val_loss: 51.1154
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0058 - val_accuracy: 0.2027 - val_loss: 52.6485
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0081 - val_accuracy: 0.1811 - val_loss: 59.5088
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0025 - val_accuracy: 0.1811 - val_loss: 59.8216
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0269 - val_accuracy: 0.1568 - val_loss: 59.8661
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0076 - val_accuracy: 0.1622 - val_loss: 62.8828
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0208 - val_accuracy: 0.2243 - val_loss: 55.1048
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0379 - val_accuracy: 0.2027 - val_loss: 63.3109
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0328 - val_accuracy: 0.2135 - val_loss: 54.1665
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9866 - loss: 0.0612 - val_accuracy: 0.1108 - val_loss: 56.7784
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9687 - loss: 0.1420 - val_accuracy: 0.2189 - val_loss: 32.3723
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9888 - loss: 0.0335 - val_accuracy: 0.1811 - val_loss: 43.6450
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0208 - val_accuracy: 0.2135 - val_loss: 43.3378
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0250 - val_accuracy: 0.2243 - val_loss: 41.3571
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.2270 - val_loss: 43.9388
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 0.2189 - val_loss: 45.0882
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.2270 - val_loss: 46.5661
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0023 - val_accuracy: 0.2270 - val_loss: 47.2500
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.2270 - val_loss: 48.1213
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9978 - loss: 0.0059 - val_accuracy: 0.2270 - val_loss: 49.8673
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0136 - val_accuracy: 0.2216 - val_loss: 43.4201
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0125 - val_accuracy: 0.2189 - val_loss: 51.3504
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0075 - val_accuracy: 0.2189 - val_loss: 46.3562
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0043 - val_accuracy: 0.2216 - val_loss: 45.3433
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9978 - loss: 0.0078 - val_accuracy: 0.2216 - val_loss: 44.7407
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0149 - val_accuracy: 0.2216 - val_loss: 47.1725
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0152 - val_accuracy: 0.2189 - val_loss: 49.4429
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0195 - val_accuracy: 0.2000 - val_loss: 51.8187
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9888 - loss: 0.0365 - val_accuracy: 0.2054 - val_loss: 35.8724
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9866 - loss: 0.0347 - val_accuracy: 0.2216 - val_loss: 33.9355
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9877 - loss: 0.0370 - val_accuracy: 0.2297 - val_loss: 42.5472
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0497 - val_accuracy: 0.2108 - val_loss: 43.5676
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0340 - val_accuracy: 0.2135 - val_loss: 41.4509
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0198 - val_accuracy: 0.2216 - val_loss: 39.1512
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9911 - loss: 0.0184 - val_accuracy: 0.2189 - val_loss: 41.4242
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.1919 - val_loss: 49.3656
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9978 - loss: 0.0055 - val_accuracy: 0.1973 - val_loss: 51.4160
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9911 - loss: 0.0291 - val_accuracy: 0.2027 - val_loss: 53.2369
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9955 - loss: 0.0314 - val_accuracy: 0.2000 - val_loss: 60.5434
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9844 - loss: 0.0588 - val_accuracy: 0.1432 - val_loss: 43.4336
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9877 - loss: 0.0612 - val_accuracy: 0.2027 - val_loss: 46.1546
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0476 - val_accuracy: 0.2378 - val_loss: 48.5390
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9966 - loss: 0.0132 - val_accuracy: 0.2730 - val_loss: 49.5748
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0363 - val_accuracy: 0.2514 - val_loss: 42.8227
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9933 - loss: 0.0547 - val_accuracy: 0.2405 - val_loss: 39.6547

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn.evaluate(X_test, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3967 - loss: 18.4623
# Test Loss: 18.4623, Test Accuracy: 39.67%

# %%
threshold = 0.5  # set the threshold value
y_pred_prob = model_cnn.predict(X_test)  # generate prediction probabilities
y_pred = (y_pred_prob > threshold).astype(int)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# --------------------------
# 1. Predict labels
# --------------------------
y_pred_probs = model_cnn.predict(X_test)   # ได้เป็น probability (softmax)
y_pred = np.argmax(y_pred_probs, axis=1)  # แปลงเป็น class index
y_true = np.argmax(y_test_cat, axis=1)    # แปลง one-hot y_test กลับเป็น index

# --------------------------
# 2. Confusion matrix
# --------------------------
cm = confusion_matrix(y_true, y_pred)

# --------------------------
# 3. Plot confusion matrix
# --------------------------
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# --------------------------
# 4. (optional) Classification report
# --------------------------
print(classification_report(y_true, y_pred, target_names=encoder.classes_))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00        89
#  Sleep stage N2       0.48      0.99      0.65        89
#  Sleep stage N3       0.67      0.72      0.69        89
#   Sleep stage R       1.00      0.42      0.59        89
#   Sleep stage W       0.00      0.00      0.00        89
#
#        accuracy                           0.42       445
#       macro avg       0.43      0.42      0.39       445
#    weighted avg       0.43      0.42      0.39       445

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
()
# Out:
# ()

# %%
print("Train class distribution:")
print(y_train_df.value_counts(normalize=True))

print("\nVal class distribution:")
print(y_val_df.value_counts(normalize=True))

print("\nTest class distribution:")
print(y_test_df.value_counts(normalize=True))
# Out:
# Train class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64
#
# Val class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64
#
# Test class distribution:
# Annotation
# Sleep stage N3    0.2
# Sleep stage R     0.2
# Sleep stage W     0.2
# Sleep stage N1    0.2
# Sleep stage N2    0.2
# Name: proportion, dtype: float64

# %% [markdown]
# ## CNN(1CH)

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np
import pandas as pd

# ----------------------------------
# 🧹 1️⃣ ล้างช่องว่างซ้ายขวา + แปลงชื่อคลาสเป็นตัวเลข
# ----------------------------------
def clean_and_encode_labels(y):
    # แปลงเป็น string ทั้งหมดก่อน (เผื่อมีบางค่าเป็น int)
    y = pd.Series(y).astype(str).str.strip()
    
    label_map = {
        'Sleep stage N1': 0,
        'Sleep stage N2': 1,
        'Sleep stage N3': 2,
        'Sleep stage R': 3,
        'Sleep stage W': 4
    }
    
    # แปลงชื่อเป็นตัวเลข
    return y.replace(label_map).astype(int).values

# ใช้ฟังก์ชันกับทุกชุด
y_train_clean = clean_and_encode_labels(y_train)
y_val_clean   = clean_and_encode_labels(y_val)
y_test_clean  = clean_and_encode_labels(y_test)

print("✅ Unique y_train_clean:", np.unique(y_train_clean))
print("✅ Unique y_val_clean:", np.unique(y_val_clean))
print("✅ Unique y_test_clean:", np.unique(y_test_clean))

# ----------------------------------
# 2️⃣ แปลงเป็น one-hot
# ----------------------------------
num_classes = 5
y_train_cat = to_categorical(y_train_clean, num_classes)
y_val_cat   = to_categorical(y_val_clean, num_classes)
y_test_cat  = to_categorical(y_test_clean, num_classes)

# -----------------------------
# 🎯 เลือกเฉพาะ 1 channel ก่อนเข้า CNN
# -----------------------------
target_channel = "EEG C4-M1"

# กรณีข้อมูลหลัง sliding window เป็น numpy array
# เช่น X_train_reduced.shape = (samples, 256, 4)
channel_names = ['EEG F4-M1', 'EEG C4-M1', 'EEG O2-M1', 'EEG C3-M2']

# หา index ของ channel เป้าหมาย
ch_idx = channel_names.index(target_channel)

# ตัดเฉพาะช่องที่ต้องการ (เหลือเพียง 1 channel)
X_train = X_train_reduced[:, :, ch_idx:ch_idx+1]
X_val   = X_val_reduced[:, :, ch_idx:ch_idx+1]
X_test  = X_test_reduced[:, :, ch_idx:ch_idx+1]

print("✅ ใช้เฉพาะ channel:", target_channel)
print("X_train shape:", X_train.shape)

# -----------------------------
# 2. แปลง X ให้เป็น float32 และ shape = (samples, timesteps, features)
# -----------------------------
X_train = np.array(X_train, dtype=np.float32)
X_val   = np.array(X_val, dtype=np.float32)
X_test  = np.array(X_test, dtype=np.float32)

if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("X_train shape:", X_train.shape)  # (samples, timesteps, channels)
print("y_train shape:", y_train_cat.shape)

# -----------------------------
# 3. สร้าง CNN model
# -----------------------------
model_cnn = Sequential([
    Conv1D(filters=32, kernel_size=7, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=128, kernel_size=3, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=64, kernel_size=5, activation='relu'),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model_cnn.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_cnn.summary()
# Out:
# ✅ Unique y_train_clean: [0 1 2 3 4]
# ✅ Unique y_val_clean: [0 1 2 3 4]
# ✅ Unique y_test_clean: [0 1 2 3 4]
# ✅ ใช้เฉพาะ channel: EEG C4-M1
# X_train shape: (1785, 1024, 1)
# X_train shape: (1785, 1024, 1)
# y_train shape: (1785, 5)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\3357808375.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\3357808375.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\3357808375.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 1018, 32)       │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1018, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 509, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 505, 64)        │        10,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 505, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 252, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 250, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 250, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 125, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 121, 64)        │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 121, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3840)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       491,648 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 569,733 (2.17 MB)
#  Trainable params: 569,157 (2.17 MB)
#  Non-trainable params: 576 (2.25 KB)

# %%
print("✅ Unique y_train_clean:", np.unique(y_train_clean))
print("✅ Unique y_val_clean:", np.unique(y_val_clean))
print("✅ Unique y_test_clean:", np.unique(y_test_clean))
print("✅ num_classes:", num_classes)
print(type(y_train_clean[0]), type(y_val_clean[0]), type(y_test_clean[0]))
# Out:
# ✅ Unique y_train_clean: [0 1 2 3 4]
# ✅ Unique y_val_clean: [0 1 2 3 4]
# ✅ Unique y_test_clean: [0 1 2 3 4]
# ✅ num_classes: 5
# <class 'numpy.int64'> <class 'numpy.int64'> <class 'numpy.int64'>

# %%
# -----------------------------
# 4. Train CNN model
# -----------------------------
history = model_cnn.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=80,
    batch_size=32,
    shuffle=True,
)
# Out:
# Epoch 1/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6331 - loss: 1.0406 - val_accuracy: 0.2054 - val_loss: 5.7226
# Epoch 2/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8655 - loss: 0.3614 - val_accuracy: 0.2027 - val_loss: 9.1182
# Epoch 3/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8992 - loss: 0.2746 - val_accuracy: 0.4313 - val_loss: 9.0497
# Epoch 4/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9300 - loss: 0.1798 - val_accuracy: 0.4503 - val_loss: 9.0308
# Epoch 5/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9574 - loss: 0.1140 - val_accuracy: 0.7116 - val_loss: 8.2050
# Epoch 6/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9636 - loss: 0.0959 - val_accuracy: 0.5551 - val_loss: 10.1460
# Epoch 7/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9585 - loss: 0.1043 - val_accuracy: 0.3891 - val_loss: 12.7211
# Epoch 8/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9776 - loss: 0.0606 - val_accuracy: 0.3551 - val_loss: 27.8609
# Epoch 9/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9877 - loss: 0.0348 - val_accuracy: 0.3306 - val_loss: 36.7921
# Epoch 10/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9810 - loss: 0.0451 - val_accuracy: 0.3415 - val_loss: 51.7121
# Epoch 11/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9787 - loss: 0.0633 - val_accuracy: 0.3497 - val_loss: 71.3821
# Epoch 12/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9905 - loss: 0.0274 - val_accuracy: 0.3442 - val_loss: 65.9183
# Epoch 13/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9765 - loss: 0.0627 - val_accuracy: 0.3769 - val_loss: 75.6500
# Epoch 14/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9776 - loss: 0.0493 - val_accuracy: 0.3769 - val_loss: 88.1562
# Epoch 15/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9888 - loss: 0.0398 - val_accuracy: 0.3034 - val_loss: 105.6757
# Epoch 16/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9882 - loss: 0.0352 - val_accuracy: 0.3687 - val_loss: 109.2577
# Epoch 17/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9888 - loss: 0.0327 - val_accuracy: 0.3687 - val_loss: 103.1844
# Epoch 18/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9866 - loss: 0.0448 - val_accuracy: 0.3755 - val_loss: 86.1621
# Epoch 19/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9826 - loss: 0.0882 - val_accuracy: 0.3265 - val_loss: 66.2970
# Epoch 20/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9669 - loss: 0.1188 - val_accuracy: 0.2585 - val_loss: 82.7244
# Epoch 21/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9899 - loss: 0.0283 - val_accuracy: 0.3374 - val_loss: 98.3089
# Epoch 22/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9905 - loss: 0.0363 - val_accuracy: 0.3020 - val_loss: 89.2008
# Epoch 23/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9905 - loss: 0.0302 - val_accuracy: 0.3020 - val_loss: 100.2934
# Epoch 24/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0256 - val_accuracy: 0.3673 - val_loss: 105.2210
# Epoch 25/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9871 - loss: 0.0362 - val_accuracy: 0.2707 - val_loss: 109.5295
# Epoch 26/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9871 - loss: 0.0371 - val_accuracy: 0.2762 - val_loss: 154.9684
# Epoch 27/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9871 - loss: 0.0605 - val_accuracy: 0.3905 - val_loss: 141.0051
# Epoch 28/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9922 - loss: 0.0238 - val_accuracy: 0.3837 - val_loss: 168.0498
# Epoch 29/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9899 - loss: 0.0237 - val_accuracy: 0.3769 - val_loss: 145.8774
# Epoch 30/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9961 - loss: 0.0129 - val_accuracy: 0.3782 - val_loss: 124.1952
# Epoch 31/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9950 - loss: 0.0252 - val_accuracy: 0.3469 - val_loss: 136.6686
# Epoch 32/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9966 - loss: 0.0113 - val_accuracy: 0.3592 - val_loss: 135.4570
# Epoch 33/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9966 - loss: 0.0073 - val_accuracy: 0.3469 - val_loss: 159.8849
# Epoch 34/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9798 - loss: 0.0935 - val_accuracy: 0.2871 - val_loss: 167.5576
# Epoch 35/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9821 - loss: 0.0599 - val_accuracy: 0.2259 - val_loss: 114.9161
# Epoch 36/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9894 - loss: 0.0258 - val_accuracy: 0.3048 - val_loss: 129.8571
# Epoch 37/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9905 - loss: 0.0293 - val_accuracy: 0.3129 - val_loss: 84.8637
# Epoch 38/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9866 - loss: 0.0457 - val_accuracy: 0.3102 - val_loss: 123.5406
# Epoch 39/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9972 - loss: 0.0069 - val_accuracy: 0.3755 - val_loss: 152.7829
# Epoch 40/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9597 - loss: 0.2353 - val_accuracy: 0.2395 - val_loss: 134.9721
# Epoch 41/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9843 - loss: 0.0515 - val_accuracy: 0.3143 - val_loss: 113.0073
# Epoch 42/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9888 - loss: 0.0436 - val_accuracy: 0.2925 - val_loss: 127.2568
# Epoch 43/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9888 - loss: 0.0347 - val_accuracy: 0.3374 - val_loss: 126.1954
# Epoch 44/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9944 - loss: 0.0148 - val_accuracy: 0.3252 - val_loss: 124.0499
# Epoch 45/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.3619 - val_loss: 109.0954
# Epoch 46/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9972 - loss: 0.0097 - val_accuracy: 0.3769 - val_loss: 146.2293
# Epoch 47/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9955 - loss: 0.0129 - val_accuracy: 0.3619 - val_loss: 135.0312
# Epoch 48/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9955 - loss: 0.0141 - val_accuracy: 0.2925 - val_loss: 134.3423
# Epoch 49/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9966 - loss: 0.0077 - val_accuracy: 0.3333 - val_loss: 152.5800
# Epoch 50/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.3279 - val_loss: 167.2887
# Epoch 51/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9944 - loss: 0.0359 - val_accuracy: 0.3537 - val_loss: 189.3124
# Epoch 52/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9871 - loss: 0.0495 - val_accuracy: 0.3429 - val_loss: 145.4223
# Epoch 53/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9972 - loss: 0.0087 - val_accuracy: 0.3782 - val_loss: 143.8223
# Epoch 54/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.9972 - loss: 0.0050 - val_accuracy: 0.3605 - val_loss: 143.6228
# Epoch 55/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9938 - loss: 0.0186 - val_accuracy: 0.3565 - val_loss: 162.0811
# Epoch 56/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9938 - loss: 0.0194 - val_accuracy: 0.3769 - val_loss: 211.0545
# Epoch 57/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9938 - loss: 0.0148 - val_accuracy: 0.3837 - val_loss: 180.0839
# Epoch 58/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9950 - loss: 0.0202 - val_accuracy: 0.3769 - val_loss: 163.7593
# Epoch 59/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9966 - loss: 0.0084 - val_accuracy: 0.3673 - val_loss: 173.7979
# Epoch 60/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9961 - loss: 0.0122 - val_accuracy: 0.3361 - val_loss: 176.8675
# Epoch 61/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9978 - loss: 0.0048 - val_accuracy: 0.3361 - val_loss: 187.7738
# Epoch 62/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.3633 - val_loss: 171.2776
# Epoch 63/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.3306 - val_loss: 217.6255
# Epoch 64/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.3442 - val_loss: 220.2848
# Epoch 65/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.3401 - val_loss: 208.2669
# Epoch 66/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9994 - loss: 0.0011 - val_accuracy: 0.3306 - val_loss: 203.0779
# Epoch 67/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9983 - loss: 0.0076 - val_accuracy: 0.3619 - val_loss: 187.5766
# Epoch 68/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 7.0227e-04 - val_accuracy: 0.3524 - val_loss: 197.1918
# Epoch 69/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9994 - loss: 0.0028 - val_accuracy: 0.3633 - val_loss: 204.0491
# Epoch 70/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9966 - loss: 0.0107 - val_accuracy: 0.3592 - val_loss: 197.6361
# Epoch 71/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9966 - loss: 0.0095 - val_accuracy: 0.3306 - val_loss: 189.0288
# Epoch 72/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9882 - loss: 0.0439 - val_accuracy: 0.3333 - val_loss: 159.0874
# Epoch 73/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9927 - loss: 0.0264 - val_accuracy: 0.3279 - val_loss: 207.3015
# Epoch 74/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9860 - loss: 0.0556 - val_accuracy: 0.2218 - val_loss: 168.3474
# Epoch 75/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9950 - loss: 0.0218 - val_accuracy: 0.3429 - val_loss: 152.0183
# Epoch 76/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9927 - loss: 0.0469 - val_accuracy: 0.3497 - val_loss: 121.9728
# Epoch 77/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9905 - loss: 0.0309 - val_accuracy: 0.3769 - val_loss: 205.1943
# Epoch 78/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9955 - loss: 0.0221 - val_accuracy: 0.3061 - val_loss: 219.3061
# Epoch 79/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9933 - loss: 0.0232 - val_accuracy: 0.3252 - val_loss: 125.8182
# Epoch 80/80
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9910 - loss: 0.0679 - val_accuracy: 0.3741 - val_loss: 188.7116

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn.evaluate(X_test, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0305 - loss: 173.8799
# Test Loss: 173.8799, Test Accuracy: 3.05%

# %%
y_pred_prob = model_cnn.predict(X_test)           # softmax probabilities
y_pred = np.argmax(y_pred_prob, axis=1)           # predicted class index
y_true = np.argmax(y_test_cat, axis=1)            # true class index
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
()
# Out:
# ()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import numpy as np

# -----------------------------
# 📊 Confusion Matrix - Test Set
# -----------------------------
y_pred = model_cnn.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

# labels ของ sleep stages
labels = ['Sleep stage N1', 'Sleep stage N2', 'Sleep stage N3', 'Sleep stage R', 'Sleep stage W']
short_labels = ['N1','N2','N3','R','W']

# Confusion Matrix (Test)
cm_test = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=short_labels, yticklabels=short_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Test Set')
plt.show()

print("\nClassification Report - Test Set")
print(classification_report(y_true, y_pred_classes, target_names=short_labels))
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Classification Report - Test Set
#               precision    recall  f1-score   support
#
#           N1       0.00      0.00      0.00       177
#           N2       0.04      0.03      0.03       177
#           N3       0.19      0.12      0.15       177
#            R       0.00      0.00      0.00       177
#            W       0.00      0.01      0.00       177
#
#     accuracy                           0.03       885
#    macro avg       0.05      0.03      0.04       885
# weighted avg       0.05      0.03      0.04       885

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# -----------------------------
# 📊 Confusion Matrix - Validation Set
# -----------------------------
y_val_pred_prob = model_cnn.predict(X_val)
y_val_pred = np.argmax(y_val_pred_prob, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

cm_val = confusion_matrix(y_val_true, y_val_pred)
plt.figure(figsize=(7,6))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues',
            xticklabels=short_labels, yticklabels=short_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')
plt.show()

# Accuracy ของ Validation set
val_acc = np.mean(y_val_pred == y_val_true)
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Validation Accuracy: 0.3741

# %%
# รับประกันว่าใช้ argmax สำหรับ softmax multi-class
y_val_probs =model_cnn.predict(X_val)   # หรือ X_val / X_val_spec ตามโมเดล
y_val_pred = np.argmax(y_val_probs, axis=1)

# ถ้า y_val_cat เป็น one-hot:
y_val_true = np.argmax(y_val_cat, axis=1)

print("Unique true:", np.unique(y_val_true, return_counts=True))
print("Unique pred:", np.unique(y_val_pred, return_counts=True))
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Unique true: (array([0, 1, 2, 3, 4]), array([147, 147, 147, 147, 147]))
# Unique pred: (array([0, 1, 2, 3, 4]), array([  5,   2,  12, 128, 588]))

# %%
from collections import Counter
most = Counter(y_train_df).most_common(1)[0][0]  # ถ้า labels เป็นตัวเลข/strings
baseline_acc = np.mean(y_val_true == most)
print("Majority class:", most, "baseline acc on val:", baseline_acc)
# Out:
# Majority class:  Sleep stage N3 baseline acc on val: 0.0

# %% [markdown]
# ## LSTM

# %%
# ----------------------------------
# 1️⃣ ฟังก์ชันแปลง label เป็นตัวเลข
# ----------------------------------
def clean_and_encode_labels(y):
    y = pd.Series(y).astype(str).str.strip()
    label_map = {
        'Sleep stage N1': 0,
        'Sleep stage N2': 1,
        'Sleep stage N3': 2,
        'Sleep stage R': 3,
        'Sleep stage W': 4
    }
    return y.replace(label_map).astype(int).values

# ----------------------------------
# 2️⃣ เตรียมข้อมูล (สมมติว่าคุณมี X_train, X_val, X_test, y_train, y_val, y_test)
# ----------------------------------
# ตัวอย่างโครงสร้าง (กรณีคุณโหลดข้อมูล EEG มาแล้ว)
# X_train.shape = (samples, timesteps, channels)
# เช่น X_train_reduced จากขั้นตอน sliding window
# หากเป็น array 2D จะเพิ่ม dimension ให้เอง

# 🔹 ใส่ข้อมูลของคุณตรงนี้ 🔹
# X_train, X_val, X_test, y_train, y_val, y_test = ...

# ----------------------------------
# 3️⃣ ทำความสะอาดและ encode label
# ----------------------------------
y_train_clean = clean_and_encode_labels(y_train)
y_val_clean   = clean_and_encode_labels(y_val)
y_test_clean  = clean_and_encode_labels(y_test)

num_classes = 5  # จำนวนคลาส N1, N2, N3, R, W

# แปลงเป็น one-hot
y_train_cat = to_categorical(y_train_clean, num_classes)
y_val_cat   = to_categorical(y_val_clean, num_classes)
y_test_cat  = to_categorical(y_test_clean, num_classes)

# ----------------------------------
# 4️⃣ ตรวจสอบ shape ของ X และแปลงเป็น float32
# ----------------------------------
X_train = np.array(X_train, dtype=np.float32)
X_val   = np.array(X_val, dtype=np.float32)
X_test  = np.array(X_test, dtype=np.float32)

# ถ้าเป็น 2D → เพิ่ม dimension (feature)
if X_train.ndim == 2:
    X_train = X_train[..., np.newaxis]
    X_val   = X_val[..., np.newaxis]
    X_test  = X_test[..., np.newaxis]

print("✅ X_train shape:", X_train.shape)
print("✅ y_train shape:", y_train_cat.shape)

# ----------------------------------
# 5️⃣ สร้าง LSTM Model
# ----------------------------------
model_lstm = Sequential([
    LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    Dropout(0.3),
    LSTM(32),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model_lstm.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

model_lstm.summary()

# ----------------------------------
# 6️⃣ Train Model
# ----------------------------------
history = model_lstm.fit(
    X_train, y_train_cat,
    validation_data=(X_val, y_val_cat),
    epochs=60,
    batch_size=32,
    shuffle=False,
    verbose=1
)

# ----------------------------------
# 7️⃣ Evaluate Model
# ----------------------------------
loss, acc = model_lstm.evaluate(X_test, y_test_cat)
print(f"✅ Test Loss: {loss:.4f}")
print(f"✅ Test Accuracy: {acc*100:.2f}%")

# ----------------------------------
# 8️⃣ Plot Learning Curves
# ----------------------------------
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# ----------------------------------
# 9️⃣ Predict + Confusion Matrix (optional)
# ----------------------------------
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred = model_lstm.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_cat, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=['N1','N2','N3','R','W'],
            yticklabels=['N1','N2','N3','R','W'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - LSTM')
plt.show()

print(classification_report(y_true, y_pred_classes, target_names=['N1','N2','N3','R','W']))
# Out:
# ✅ X_train shape: (1785, 1024, 1)
# ✅ y_train shape: (1785, 5)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\171322584.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\171322584.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_21712\171322584.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return y.replace(label_map).astype(int).values
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1024, 64)       │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31,749 (124.02 KB)
#  Trainable params: 31,749 (124.02 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 22s 358ms/step - accuracy: 0.2134 - loss: 1.6415 - val_accuracy: 0.1946 - val_loss: 1.7484
# Epoch 2/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 336ms/step - accuracy: 0.0818 - loss: 1.7292 - val_accuracy: 0.2367 - val_loss: 1.6055
# Epoch 3/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 333ms/step - accuracy: 0.0818 - loss: 1.6643 - val_accuracy: 0.2041 - val_loss: 1.6105
# Epoch 4/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 328ms/step - accuracy: 0.1081 - loss: 1.6421 - val_accuracy: 0.2299 - val_loss: 1.6089
# Epoch 5/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - accuracy: 0.0952 - loss: 1.6196 - val_accuracy: 0.1891 - val_loss: 1.6087
# Epoch 6/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 328ms/step - accuracy: 0.1675 - loss: 1.6165 - val_accuracy: 0.2476 - val_loss: 1.6085
# Epoch 7/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 331ms/step - accuracy: 0.1826 - loss: 1.6157 - val_accuracy: 0.2544 - val_loss: 1.6083
# Epoch 8/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 332ms/step - accuracy: 0.1591 - loss: 1.6150 - val_accuracy: 0.2667 - val_loss: 1.6078
# Epoch 9/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 330ms/step - accuracy: 0.1546 - loss: 1.6151 - val_accuracy: 0.2476 - val_loss: 1.6076
# Epoch 10/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 332ms/step - accuracy: 0.1305 - loss: 1.6149 - val_accuracy: 0.2612 - val_loss: 1.6071
# Epoch 11/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 18s 330ms/step - accuracy: 0.1328 - loss: 1.6153 - val_accuracy: 0.2571 - val_loss: 1.6065
# Epoch 12/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 332ms/step - accuracy: 0.1232 - loss: 1.6178 - val_accuracy: 0.2367 - val_loss: 1.6064
# Epoch 13/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 336ms/step - accuracy: 0.0913 - loss: 1.6161 - val_accuracy: 0.2571 - val_loss: 1.6062
# Epoch 14/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - accuracy: 0.0919 - loss: 1.6140 - val_accuracy: 0.2517 - val_loss: 1.6047
# Epoch 15/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 334ms/step - accuracy: 0.1008 - loss: 1.6146 - val_accuracy: 0.2476 - val_loss: 1.6043
# Epoch 16/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 338ms/step - accuracy: 0.0863 - loss: 1.6135 - val_accuracy: 0.2449 - val_loss: 1.6036
# Epoch 17/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - accuracy: 0.0728 - loss: 1.6146 - val_accuracy: 0.2449 - val_loss: 1.6029
# Epoch 18/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 336ms/step - accuracy: 0.0756 - loss: 1.6142 - val_accuracy: 0.2476 - val_loss: 1.6027
# Epoch 19/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 334ms/step - accuracy: 0.0796 - loss: 1.6123 - val_accuracy: 0.2354 - val_loss: 1.6009
# Epoch 20/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 337ms/step - accuracy: 0.0672 - loss: 1.6150 - val_accuracy: 0.2395 - val_loss: 1.6039
# Epoch 21/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 338ms/step - accuracy: 0.0711 - loss: 1.6152 - val_accuracy: 0.2245 - val_loss: 1.6035
# Epoch 22/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 19s 343ms/step - accuracy: 0.0723 - loss: 1.6163 - val_accuracy: 0.2190 - val_loss: 1.6040
# Epoch 23/60
# 29/56 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.1588 - loss: 1.5996
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 77
#      72 model_lstm.summary()
#      74 # ----------------------------------
#      75 # 6️⃣ Train Model
#      76 # ----------------------------------
# ---> 77 history = model_lstm.fit(
#      78     X_train, y_train_cat,
#      79     validation_data=(X_val, y_val_cat),
#      80     epochs=60,
#      81     batch_size=32,
#      82     shuffle=False,
#      83     verbose=1
#      84 )
#      86 # ----------------------------------
#      87 # 7️⃣ Evaluate Model
#      88 # ----------------------------------
#      89 loss, acc = model_lstm.evaluate(X_test, y_test_cat)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for begin_step, end_step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(begin_step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(end_step, logs)
#     379     if self.stop_training:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# ---- พยากรณ์บน validation set ----
y_val_pred_prob = model_lstm.predict(X_val)
y_val_pred = np.argmax(y_val_pred_prob, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

# ---- คำนวณ confusion matrix ----
cm_val = confusion_matrix(y_val_true, y_val_pred)

# ✅ ใช้ label ตามลำดับที่เรากำหนดไว้ใน clean_and_encode_labels()
labels = ['N1', 'N2', 'N3', 'R', 'W']

# ---- แสดง confusion matrix ----
plt.figure(figsize=(7,6))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix - Validation Set')
plt.show()

# ---- แสดง accuracy เพิ่มเติม ----
val_acc = np.mean(y_val_pred == y_val_true)
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# Validation Accuracy: 0.3172

# %% [markdown]
# ## Spectrogram CNN

# %%
from scipy.signal import spectrogram
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# -----------------------------
# 1. Compute spectrogram function
# -----------------------------
def compute_spectrogram(signal, fs=100, nperseg=128, noverlap=64):
    f, t, Sxx = spectrogram(signal, fs=fs, nperseg=min(nperseg, len(signal)), 
                            noverlap=min(noverlap, len(signal)//2))
    return np.log1p(Sxx)

# -----------------------------
# 2. Transform X_train, X_val, X_test → Spectrogram
# -----------------------------
def dataset_to_spectrogram(X, fs=100, nperseg=128, noverlap=64):
    specs = []
    for x in X:  # x.shape = (timesteps, channels)
        ch_specs = [compute_spectrogram(x[:, ch], fs, nperseg, noverlap) 
                    for ch in range(x.shape[1])]
        specs.append(np.stack(ch_specs, axis=-1))  # (freq_bins, time_bins, channels)
    return np.array(specs)

# เพิ่ม channel dimension (เหมือนภาพขาวดำ)
# แปลง dataset ทั้งหมด
X_train_spec = dataset_to_spectrogram(X_train)
X_val_spec   = dataset_to_spectrogram(X_val)
X_test_spec  = dataset_to_spectrogram(X_test)

print("X_train_spec:", X_train_spec.shape)
print("X_val_spec:", X_val_spec.shape)
print("X_test_spec:", X_test_spec.shape)
# -----------------------------
# 3. Encode labels
# -----------------------------
encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_val_enc   = encoder.transform(y_val)
y_test_enc  = encoder.transform(y_test)

num_classes = len(np.unique(y_train_enc))
y_train_cat = to_categorical(y_train_enc, num_classes=num_classes)
y_val_cat   = to_categorical(y_val_enc, num_classes=num_classes)
y_test_cat  = to_categorical(y_test_enc, num_classes=num_classes)

# -----------------------------
# 4. CNN Model (simple)
# -----------------------------
model_cnn_spec = Sequential([
    Conv2D(32, (3,3), activation='relu',padding='same', input_shape=X_train_spec.shape[1:]),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same',),

    Conv2D(64, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Conv2D(128, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Conv2D(64, (3,3), activation='relu',padding='same'),
    BatchNormalization(),
    MaxPooling2D((2,2),padding='same'),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax',)
])

model_cnn_spec.compile(optimizer='adam',
                       loss='categorical_crossentropy',
                       metrics=['accuracy'])

model_cnn_spec.summary()
# Out:
# X_train_spec: (355, 65, 39, 1)
# X_val_spec: (145, 65, 39, 1)
# X_test_spec: (175, 65, 39, 1)
# C:\Users\ADMIN\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 65, 39, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 65, 39, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 33, 20, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 33, 20, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 33, 20, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 17, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 17, 10, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 17, 10, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 9, 5, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 9, 5, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 9, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 5, 3, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 960)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │       123,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 291,269 (1.11 MB)
#  Trainable params: 290,693 (1.11 MB)
#  Non-trainable params: 576 (2.25 KB)

# %%
# -----------------------------
# 5. Train model (no class weight)
# -----------------------------
history = model_cnn_spec.fit(
    X_train_spec, y_train_cat,
    validation_data=(X_val_spec, y_val_cat),
    epochs=100,
    batch_size=32,
    shuffle=True
)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.2676 - loss: 2.2607 - val_accuracy: 0.2000 - val_loss: 1.5759
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4225 - loss: 1.4057 - val_accuracy: 0.2138 - val_loss: 1.5497
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4901 - loss: 1.2153 - val_accuracy: 0.2207 - val_loss: 1.5151
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5521 - loss: 1.0572 - val_accuracy: 0.2207 - val_loss: 1.5661
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.5465 - loss: 1.0499 - val_accuracy: 0.2207 - val_loss: 1.6150
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.5690 - loss: 1.0131 - val_accuracy: 0.2138 - val_loss: 1.6676
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6535 - loss: 0.8590 - val_accuracy: 0.2069 - val_loss: 1.7516
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6451 - loss: 0.7912 - val_accuracy: 0.2069 - val_loss: 1.7874
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6958 - loss: 0.7361 - val_accuracy: 0.2069 - val_loss: 1.9772
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7268 - loss: 0.6799 - val_accuracy: 0.2000 - val_loss: 2.2953
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7944 - loss: 0.5176 - val_accuracy: 0.1586 - val_loss: 2.2248
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8056 - loss: 0.5319 - val_accuracy: 0.1655 - val_loss: 2.3915
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8056 - loss: 0.4747 - val_accuracy: 0.1379 - val_loss: 2.3587
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.8563 - loss: 0.3894 - val_accuracy: 0.1448 - val_loss: 2.4311
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8817 - loss: 0.3193 - val_accuracy: 0.1379 - val_loss: 2.7377
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8761 - loss: 0.3158 - val_accuracy: 0.1793 - val_loss: 2.9374
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8648 - loss: 0.3595 - val_accuracy: 0.2000 - val_loss: 2.3057
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8197 - loss: 0.5469 - val_accuracy: 0.2000 - val_loss: 2.7613
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8225 - loss: 0.4560 - val_accuracy: 0.1517 - val_loss: 2.1239
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8620 - loss: 0.3337 - val_accuracy: 0.2000 - val_loss: 2.7811
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9239 - loss: 0.2291 - val_accuracy: 0.2000 - val_loss: 2.7678
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9408 - loss: 0.2098 - val_accuracy: 0.2069 - val_loss: 2.6444
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9380 - loss: 0.1578 - val_accuracy: 0.2069 - val_loss: 2.4062
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9775 - loss: 0.0841 - val_accuracy: 0.2069 - val_loss: 2.3983
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9493 - loss: 0.1569 - val_accuracy: 0.2828 - val_loss: 2.0183
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9352 - loss: 0.1792 - val_accuracy: 0.4000 - val_loss: 2.8232
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9662 - loss: 0.1050 - val_accuracy: 0.3931 - val_loss: 3.3142
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7718 - loss: 0.6915 - val_accuracy: 0.4000 - val_loss: 2.9835
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7859 - loss: 0.4821 - val_accuracy: 0.5034 - val_loss: 2.2089
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8732 - loss: 0.3049 - val_accuracy: 0.4276 - val_loss: 3.1315
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9437 - loss: 0.1978 - val_accuracy: 0.5586 - val_loss: 4.0333
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9127 - loss: 0.2035 - val_accuracy: 0.4207 - val_loss: 4.5061
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8169 - loss: 0.5658 - val_accuracy: 0.5517 - val_loss: 2.7406
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8873 - loss: 0.3126 - val_accuracy: 0.2483 - val_loss: 6.8181
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9493 - loss: 0.1614 - val_accuracy: 0.2483 - val_loss: 7.3385
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9549 - loss: 0.1209 - val_accuracy: 0.2690 - val_loss: 7.6204
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9831 - loss: 0.0673 - val_accuracy: 0.2000 - val_loss: 11.7500
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9746 - loss: 0.0812 - val_accuracy: 0.2828 - val_loss: 9.4421
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9915 - loss: 0.0429 - val_accuracy: 0.2000 - val_loss: 10.9896
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9718 - loss: 0.0790 - val_accuracy: 0.2000 - val_loss: 14.4300
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9606 - loss: 0.1074 - val_accuracy: 0.2000 - val_loss: 13.6769
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9521 - loss: 0.1084 - val_accuracy: 0.2759 - val_loss: 15.6311
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9718 - loss: 0.0867 - val_accuracy: 0.2069 - val_loss: 16.8968
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9521 - loss: 0.1185 - val_accuracy: 0.2000 - val_loss: 16.7355
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9662 - loss: 0.1158 - val_accuracy: 0.2000 - val_loss: 21.9713
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9127 - loss: 0.2634 - val_accuracy: 0.2000 - val_loss: 23.1836
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9634 - loss: 0.1217 - val_accuracy: 0.2000 - val_loss: 24.5750
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9775 - loss: 0.0935 - val_accuracy: 0.2000 - val_loss: 25.2406
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9775 - loss: 0.0589 - val_accuracy: 0.2000 - val_loss: 28.9423
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9972 - loss: 0.0239 - val_accuracy: 0.2000 - val_loss: 29.7476
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9944 - loss: 0.0218 - val_accuracy: 0.2000 - val_loss: 32.2728
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9972 - loss: 0.0170 - val_accuracy: 0.2000 - val_loss: 31.9198
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9972 - loss: 0.0175 - val_accuracy: 0.2000 - val_loss: 37.3220
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9944 - loss: 0.0165 - val_accuracy: 0.2000 - val_loss: 33.1861
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.2000 - val_loss: 38.3377
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9831 - loss: 0.0336 - val_accuracy: 0.2000 - val_loss: 41.3468
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9972 - loss: 0.0158 - val_accuracy: 0.2000 - val_loss: 41.0494
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9944 - loss: 0.0155 - val_accuracy: 0.2000 - val_loss: 45.3388
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9944 - loss: 0.0088 - val_accuracy: 0.2000 - val_loss: 51.9616
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9972 - loss: 0.0127 - val_accuracy: 0.2000 - val_loss: 54.3259
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9831 - loss: 0.0436 - val_accuracy: 0.2000 - val_loss: 52.8212
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9972 - loss: 0.0204 - val_accuracy: 0.2000 - val_loss: 47.9769
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9859 - loss: 0.0375 - val_accuracy: 0.2000 - val_loss: 52.1917
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.2000 - val_loss: 59.6136
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.2000 - val_loss: 58.9015
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9972 - loss: 0.0092 - val_accuracy: 0.2000 - val_loss: 60.0764
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.2000 - val_loss: 60.4673
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9972 - loss: 0.0131 - val_accuracy: 0.2000 - val_loss: 64.4047
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9944 - loss: 0.0357 - val_accuracy: 0.2000 - val_loss: 60.2870
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8817 - loss: 0.5319 - val_accuracy: 0.2000 - val_loss: 71.2423
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8620 - loss: 0.3564 - val_accuracy: 0.2000 - val_loss: 73.7791
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9352 - loss: 0.1896 - val_accuracy: 0.2000 - val_loss: 67.8488
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9718 - loss: 0.0873 - val_accuracy: 0.2000 - val_loss: 64.5048
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9549 - loss: 0.1214 - val_accuracy: 0.2000 - val_loss: 79.0489
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9268 - loss: 0.2090 - val_accuracy: 0.2000 - val_loss: 66.9427
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9606 - loss: 0.1212 - val_accuracy: 0.2000 - val_loss: 66.2063
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9775 - loss: 0.0653 - val_accuracy: 0.2000 - val_loss: 65.1420
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9606 - loss: 0.1093 - val_accuracy: 0.2000 - val_loss: 69.6224
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9775 - loss: 0.0478 - val_accuracy: 0.2000 - val_loss: 65.0065
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9831 - loss: 0.0430 - val_accuracy: 0.2000 - val_loss: 68.6484
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9887 - loss: 0.0432 - val_accuracy: 0.2000 - val_loss: 71.7378
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9718 - loss: 0.0965 - val_accuracy: 0.2000 - val_loss: 86.0644
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8507 - loss: 0.5599 - val_accuracy: 0.2000 - val_loss: 85.8186
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9042 - loss: 0.2462 - val_accuracy: 0.2000 - val_loss: 54.1896
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9296 - loss: 0.1878 - val_accuracy: 0.2000 - val_loss: 53.3830
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9690 - loss: 0.0862 - val_accuracy: 0.2000 - val_loss: 53.9995
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9915 - loss: 0.0501 - val_accuracy: 0.2000 - val_loss: 60.7297
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9746 - loss: 0.0571 - val_accuracy: 0.2000 - val_loss: 56.2157
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9831 - loss: 0.0780 - val_accuracy: 0.2000 - val_loss: 60.1264
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9972 - loss: 0.0264 - val_accuracy: 0.2000 - val_loss: 68.5508
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9662 - loss: 0.1245 - val_accuracy: 0.2000 - val_loss: 68.4258
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8901 - loss: 0.5084 - val_accuracy: 0.2000 - val_loss: 82.4174
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9408 - loss: 0.2582 - val_accuracy: 0.2000 - val_loss: 88.2442
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9775 - loss: 0.0846 - val_accuracy: 0.2000 - val_loss: 90.2884
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9803 - loss: 0.0473 - val_accuracy: 0.2000 - val_loss: 99.0228
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9887 - loss: 0.0361 - val_accuracy: 0.2000 - val_loss: 95.4933
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9831 - loss: 0.0448 - val_accuracy: 0.2000 - val_loss: 99.8237
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9831 - loss: 0.0474 - val_accuracy: 0.2000 - val_loss: 94.8122
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9944 - loss: 0.0216 - val_accuracy: 0.2000 - val_loss: 82.0050
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.2000 - val_loss: 87.7948

# %%
# -----------------------------
# 5. Evaluate model
# -----------------------------
loss, accuracy = model_cnn_spec.evaluate(X_test_spec, y_test_cat)
print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy * 100:.2f}%")
threshold = 0.5  # set the threshold value
y_pred_prob = model_cnn_spec.predict(X_test_spec)  # generate prediction probabilities
y_pred = (y_pred_prob > threshold).astype(int)
# ----------------------------------
# 8️⃣ Plot Learning Curves
# ----------------------------------
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.2971 - loss: 6.3955
# Test Loss: 6.3955, Test Accuracy: 29.71%
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# ======================================================
# 🔹 1️⃣ Validation Set
# ======================================================
print("=== Confusion Matrix : Validation Set ===")

# Predict labels on validation set
y_val_pred_probs = model_cnn_spec.predict(X_val_spec)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)
y_val_true = np.argmax(y_val_cat, axis=1)

# Compute confusion matrix
cm_val = confusion_matrix(y_val_true, y_val_pred, labels=range(num_classes))

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm_val, annot=True, fmt="d", cmap="Greens",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Validation Set")
plt.show()

# Print classification report
print(classification_report(y_val_true, y_val_pred,
                            labels=range(num_classes),
                            target_names=encoder.classes_))

val_acc = np.mean(y_val_pred == y_val_true)
print(f"✅ Validation Accuracy: {val_acc * 100:.2f}%\n")


# ======================================================
# 🔹 2️⃣ Test Set
# ======================================================
print("=== Confusion Matrix : Test Set ===")

# Predict labels on test set
y_test_pred_probs = model_cnn_spec.predict(X_test_spec)
y_test_pred = np.argmax(y_test_pred_probs, axis=1)
y_test_true = np.argmax(y_test_cat, axis=1)

# Compute confusion matrix
cm_test = confusion_matrix(y_test_true, y_test_pred, labels=range(num_classes))

# Plot confusion matrix
plt.figure(figsize=(8,6))
sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
            xticklabels=encoder.classes_,
            yticklabels=encoder.classes_)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix - Test Set")
plt.show()

# Print classification report
print(classification_report(y_test_true, y_test_pred,
                            labels=range(num_classes),
                            target_names=encoder.classes_))

test_acc = np.mean(y_test_pred == y_test_true)
print(f"✅ Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# === Confusion Matrix : Validation Set ===
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00       299
#  Sleep stage N2       0.00      0.00      0.00       299
#  Sleep stage N3       0.33      0.00      0.01       299
#   Sleep stage R       0.37      0.08      0.14       299
#   Sleep stage W       0.29      0.97      0.45       299
#
#        accuracy                           0.21      1495
#       macro avg       0.20      0.21      0.12      1495
#    weighted avg       0.20      0.21      0.12      1495
#
# ✅ Validation Accuracy: 21.14%
#
# === Confusion Matrix : Test Set ===
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#                  precision    recall  f1-score   support
#
#  Sleep stage N1       0.00      0.00      0.00       359
#  Sleep stage N2       0.42      1.00      0.60       359
#  Sleep stage N3       0.69      0.21      0.32       359
#   Sleep stage R       1.00      0.80      0.89       359
#   Sleep stage W       0.00      0.00      0.00       359
#
#        accuracy                           0.40      1795
#       macro avg       0.42      0.40      0.36      1795
#    weighted avg       0.42      0.40      0.36      1795
#
# ✅ Test Accuracy: 40.17%
